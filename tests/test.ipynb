# %%
import os
import sys

sys.path.insert(0, os.path.abspath(
    os.path.join(os.path.dirname('__file__'), '..')))
from src.encoders.tools import create_encoding_pipeline
import pandas as pd
from sklearn.preprocessing import StandardScaler, OneHotEncoder, MinMaxScaler, RobustScaler
from category_encoders import TargetEncoder, CatBoostEncoder
from feature_engine.creation import CyclicalFeatures
from sklearn import set_config

# %%
data = pd.DataFrame({
    'num_feature1': [1.0, 2.0, 3.0, 4.0],
    'num_feature2': [10.0, 20.0, 30.0, 40.0],
    'cat_feature1': ['A', 'B', 'A', 'B'],
    'cat_feature2': ['X', 'Y', 'X', 'Y'],
    'date_feature': pd.to_datetime(['2021-01-01', '2021-01-27', '2021-01-03', '2021-03-26'])
})

y = pd.Series([1, 0, 1, 0])

data['num_feature1'] = data['num_feature1'].astype('float')
data['num_feature2'] = data['num_feature2'].astype('float')
data['cat_feature1'] = data['cat_feature1'].astype('category')
data['cat_feature2'] = data['cat_feature2'].astype('category')
data['date_feature'] = pd.to_datetime(data['date_feature'])

# %%
test_data = pd.DataFrame({
    'num_feature1': [5.0],
    'num_feature2': [50.0],
    'cat_feature1': ['A'],
    'cat_feature2': ['X'],
    'date_feature': pd.to_datetime(['2021-03-27'])
})

test_data['num_feature1'] = test_data['num_feature1'].astype('float')
test_data['num_feature2'] = test_data['num_feature2'].astype('float')
test_data['cat_feature1'] = test_data['cat_feature1'].astype('category')
test_data['cat_feature2'] = test_data['cat_feature2'].astype('category')
test_data['date_feature'] = pd.to_datetime(test_data['date_feature'])

# %%
encoders_dict = {
    'number': [
        StandardScaler(),
        # MinMaxScaler(),
        # RobustScaler()
    ],
    'category': [
        # OneHotEncoder(sparse_output=False),
        TargetEncoder(),
        # CatBoostEncoder()
    ],
    'datetime': {
        'as_number': [
            CyclicalFeatures(drop_original=True)
        ],
        'as_category': [
             TargetEncoder(),
            #  CatBoostEncoder()
        ]
    }
}

# %%
processor = create_encoding_pipeline(encoders_dict)
# Out:
# Creating encoding pipeline

# %%
processor
# Out:
# Pipeline(steps=[('columntransformer-1',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('pipeline',
#                                                   Pipeline(steps=[('simpleimputer',
#                                                                    SimpleImputer()),
#                                                                   ('featureunion',
#                                                                    FeatureUnion(transformer_list=[('standardscaler',
#                                                                                                    StandardScaler())]))]),
#                                                   <sklearn.compose._column_transformer.make_column_selector object at 0x7e6a139fba60>)])),
#                 ('columntransformer-...
#                                                                                                     <sklearn.compose._column_transformer.make_column_selector object at 0x7e6a139fbc70>)])),
#                                                                   ('columntransformer-2',
#                                                                    ColumnTransformer(remainder='passthrough',
#                                                                                      transformers=[('featureunion',
#                                                                                                     FeatureUnion(transformer_list=[('targetencoder',
#                                                                                                                                     TargetEncoder())]),
#                                                                                                     <sklearn.compose._column_transformer.make_column_selector object at 0x7e6a139fa050>)]))]),
#                                                   <sklearn.compose._column_transformer.make_column_selector object at 0x7e6a139fb850>)]))],
#          verbose=True)

# %%
processor.fit(data, y)
processor
# Out:
# [Pipeline]  (step 1 of 3) Processing columntransformer-1, total=   0.0s
# [Pipeline]  (step 2 of 3) Processing columntransformer-2, total=   0.0s
# [Pipeline]  (step 3 of 3) Processing columntransformer-3, total=   0.1s
# /home/maxime/Documents/WORKSPACES/forecasting_models/.venv/lib/python3.10/site-packages/category_encoders/ordinal.py:198: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   X[column] = X[column].astype("object").fillna(np.nan).map(col_mapping)
# /home/maxime/Documents/WORKSPACES/forecasting_models/.venv/lib/python3.10/site-packages/category_encoders/ordinal.py:198: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   X[column] = X[column].astype("object").fillna(np.nan).map(col_mapping)
# /home/maxime/Documents/WORKSPACES/forecasting_models/.venv/lib/python3.10/site-packages/category_encoders/ordinal.py:198: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   X[column] = X[column].astype("object").fillna(np.nan).map(col_mapping)
# /home/maxime/Documents/WORKSPACES/forecasting_models/.venv/lib/python3.10/site-packages/category_encoders/ordinal.py:198: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   X[column] = X[column].astype("object").fillna(np.nan).map(col_mapping)
# /home/maxime/Documents/WORKSPACES/forecasting_models/.venv/lib/python3.10/site-packages/category_encoders/ordinal.py:198: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   X[column] = X[column].astype("object").fillna(np.nan).map(col_mapping)
# /home/maxime/Documents/WORKSPACES/forecasting_models/.venv/lib/python3.10/site-packages/category_encoders/ordinal.py:198: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   X[column] = X[column].astype("object").fillna(np.nan).map(col_mapping)
# /home/maxime/Documents/WORKSPACES/forecasting_models/.venv/lib/python3.10/site-packages/category_encoders/ordinal.py:198: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   X[column] = X[column].astype("object").fillna(np.nan).map(col_mapping)
# /home/maxime/Documents/WORKSPACES/forecasting_models/.venv/lib/python3.10/site-packages/category_encoders/ordinal.py:198: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   X[column] = X[column].astype("object").fillna(np.nan).map(col_mapping)
# /home/maxime/Documents/WORKSPACES/forecasting_models/.venv/lib/python3.10/site-packages/category_encoders/ordinal.py:198: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   X[column] = X[column].astype("object").fillna(np.nan).map(col_mapping)
# /home/maxime/Documents/WORKSPACES/forecasting_models/.venv/lib/python3.10/site-packages/category_encoders/ordinal.py:198: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   X[column] = X[column].astype("object").fillna(np.nan).map(col_mapping)
# /home/maxime/Documents/WORKSPACES/forecasting_models/.venv/lib/python3.10/site-packages/category_encoders/ordinal.py:198: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   X[column] = X[column].astype("object").fillna(np.nan).map(col_mapping)
# /home/maxime/Documents/WORKSPACES/forecasting_models/.venv/lib/python3.10/site-packages/category_encoders/ordinal.py:198: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   X[column] = X[column].astype("object").fillna(np.nan).map(col_mapping)
# /home/maxime/Documents/WORKSPACES/forecasting_models/.venv/lib/python3.10/site-packages/category_encoders/ordinal.py:198: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   X[column] = X[column].astype("object").fillna(np.nan).map(col_mapping)
# /home/maxime/Documents/WORKSPACES/forecasting_models/.venv/lib/python3.10/site-packages/category_encoders/ordinal.py:198: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   X[column] = X[column].astype("object").fillna(np.nan).map(col_mapping)
# /home/maxime/Documents/WORKSPACES/forecasting_models/.venv/lib/python3.10/site-packages/category_encoders/ordinal.py:198: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   X[column] = X[column].astype("object").fillna(np.nan).map(col_mapping)
# /home/maxime/Documents/WORKSPACES/forecasting_models/.venv/lib/python3.10/site-packages/category_encoders/ordinal.py:198: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   X[column] = X[column].astype("object").fillna(np.nan).map(col_mapping)
# /home/maxime/Documents/WORKSPACES/forecasting_models/.venv/lib/python3.10/site-packages/category_encoders/ordinal.py:198: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   X[column] = X[column].astype("object").fillna(np.nan).map(col_mapping)
# /home/maxime/Documents/WORKSPACES/forecasting_models/.venv/lib/python3.10/site-packages/category_encoders/ordinal.py:198: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   X[column] = X[column].astype("object").fillna(np.nan).map(col_mapping)
# /home/maxime/Documents/WORKSPACES/forecasting_models/.venv/lib/python3.10/site-packages/category_encoders/ordinal.py:198: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   X[column] = X[column].astype("object").fillna(np.nan).map(col_mapping)
# /home/maxime/Documents/WORKSPACES/forecasting_models/.venv/lib/python3.10/site-packages/category_encoders/ordinal.py:198: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   X[column] = X[column].astype("object").fillna(np.nan).map(col_mapping)
# Pipeline(steps=[('columntransformer-1',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('pipeline',
#                                                   Pipeline(steps=[('simpleimputer',
#                                                                    SimpleImputer()),
#                                                                   ('featureunion',
#                                                                    FeatureUnion(transformer_list=[('standardscaler',
#                                                                                                    StandardScaler())]))]),
#                                                   <sklearn.compose._column_transformer.make_column_selector object at 0x7e6a139fba60>)])),
#                 ('columntransformer-...
#                                                                                                     <sklearn.compose._column_transformer.make_column_selector object at 0x7e6a139fbc70>)])),
#                                                                   ('columntransformer-2',
#                                                                    ColumnTransformer(remainder='passthrough',
#                                                                                      transformers=[('featureunion',
#                                                                                                     FeatureUnion(transformer_list=[('targetencoder',
#                                                                                                                                     TargetEncoder())]),
#                                                                                                     <sklearn.compose._column_transformer.make_column_selector object at 0x7e6a139fa050>)]))]),
#                                                   <sklearn.compose._column_transformer.make_column_selector object at 0x7e6a139fb850>)]))],
#          verbose=True)

# %%
encoded = processor.transform(data)
print(encoded)
# Out:
#    pipeline__featureunion__targetencoder__remainder__remainder__remainder__date_feature_month_cat  \
# 0                                           0.525744
# 1                                           0.525744
# 2                                           0.525744
# 3                                           0.434946
#
#    pipeline__featureunion__targetencoder__remainder__remainder__remainder__date_feature_day_cat  \
# 0                                           0.565054
# 1                                           0.434946
# 2                                           0.565054
# 3                                           0.434946
#
#    pipeline__featureunion__targetencoder__remainder__remainder__remainder__date_feature_dayofweek_cat  \
# 0                                           0.500000
# 1                                           0.434946
# 2                                           0.565054
# 3                                           0.500000
#
#    pipeline__featureunion__targetencoder__remainder__remainder__remainder__date_feature_week_cat  \
# 0                                           0.570926
# 1                                           0.434946
# 2                                           0.570926
# 3                                           0.434946
#
#    pipeline__featureunion__targetencoder__remainder__remainder__remainder__date_feature_dayofYear_cat  \
# 0                                           0.565054
# 1                                           0.434946
# 2                                           0.565054
# 3                                           0.434946
#
#    pipeline__remainder__featureunion__cyclicalfeatures__remainder__remainder__date_feature_month_sin  \
# 0                                       8.660254e-01
# 1                                       8.660254e-01
# 2                                       8.660254e-01
# 3                                      -2.449294e-16
#
#    pipeline__remainder__featureunion__cyclicalfeatures__remainder__remainder__date_feature_month_cos  \
# 0                                               -0.5
# 1                                               -0.5
# 2                                               -0.5
# 3                                                1.0
#
#    pipeline__remainder__featureunion__cyclicalfeatures__remainder__remainder__date_feature_day_sin  \
# 0                                       2.306159e-01
# 1                                      -2.449294e-16
# 2                                       6.427876e-01
# 3                                      -2.306159e-01
#
#    pipeline__remainder__featureunion__cyclicalfeatures__remainder__remainder__date_feature_day_cos  \
# 0                                           0.973045
# 1                                           1.000000
# 2                                           0.766044
# 3                                           0.973045
#
#    pipeline__remainder__featureunion__cyclicalfeatures__remainder__remainder__date_feature_dayofweek_sin  \
# 0                                      -8.660254e-01
# 1                                       8.660254e-01
# 2                                      -2.449294e-16
# 3                                      -8.660254e-01
#
#    pipeline__remainder__featureunion__cyclicalfeatures__remainder__remainder__date_feature_dayofweek_cos  \
# 0                                               -0.5
# 1                                               -0.5
# 2                                                1.0
# 3                                               -0.5
#
#    pipeline__remainder__featureunion__cyclicalfeatures__remainder__remainder__date_feature_week_sin  \
# 0                                               -0.0
# 1                                           0.456629
# 2                                               -0.0
# 3                                            0.98904
#
#    pipeline__remainder__featureunion__cyclicalfeatures__remainder__remainder__date_feature_week_cos  \
# 0                                                1.0
# 1                                           0.889657
# 2                                                1.0
# 3                                           0.147647
#
#    pipeline__remainder__featureunion__cyclicalfeatures__remainder__remainder__date_feature_dayofYear_sin  \
# 0                                       7.299531e-02
# 1                                       9.203462e-01
# 2                                       2.174302e-01
# 3                                      -2.449294e-16
#
#    pipeline__remainder__featureunion__cyclicalfeatures__remainder__remainder__date_feature_dayofYear_cos  \
# 0                                           0.997332
# 1                                          -0.391105
# 2                                           0.976076
# 3                                           1.000000
#
#    remainder__pipeline__targetencoder__remainder__cat_feature1  \
# 0                                           0.570926
# 1                                           0.429074
# 2                                           0.570926
# 3                                           0.429074
#
#    remainder__pipeline__targetencoder__remainder__cat_feature2  \
# 0                                           0.570926
# 1                                           0.429074
# 2                                           0.570926
# 3                                           0.429074
#
#    remainder__remainder__pipeline__standardscaler__num_feature1  \
# 0                                          -1.341641
# 1                                          -0.447214
# 2                                           0.447214
# 3                                           1.341641
#
#    remainder__remainder__pipeline__standardscaler__num_feature2
# 0                                          -1.341641
# 1                                          -0.447214
# 2                                           0.447214
# 3                                           1.341641
# /home/maxime/Documents/WORKSPACES/forecasting_models/.venv/lib/python3.10/site-packages/category_encoders/ordinal.py:198: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   X[column] = X[column].astype("object").fillna(np.nan).map(col_mapping)
# /home/maxime/Documents/WORKSPACES/forecasting_models/.venv/lib/python3.10/site-packages/category_encoders/ordinal.py:198: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   X[column] = X[column].astype("object").fillna(np.nan).map(col_mapping)
# /home/maxime/Documents/WORKSPACES/forecasting_models/.venv/lib/python3.10/site-packages/category_encoders/ordinal.py:198: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   X[column] = X[column].astype("object").fillna(np.nan).map(col_mapping)
# /home/maxime/Documents/WORKSPACES/forecasting_models/.venv/lib/python3.10/site-packages/category_encoders/ordinal.py:198: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   X[column] = X[column].astype("object").fillna(np.nan).map(col_mapping)
# /home/maxime/Documents/WORKSPACES/forecasting_models/.venv/lib/python3.10/site-packages/category_encoders/ordinal.py:198: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   X[column] = X[column].astype("object").fillna(np.nan).map(col_mapping)

# %%
encoded = processor.transform(test_data)
print(encoded)
# Out:
#    pipeline__featureunion__targetencoder__remainder__remainder__remainder__date_feature_month_cat  \
# 0                                           0.434946
#
#    pipeline__featureunion__targetencoder__remainder__remainder__remainder__date_feature_day_cat  \
# 0                                           0.434946
#
#    pipeline__featureunion__targetencoder__remainder__remainder__remainder__date_feature_dayofweek_cat  \
# 0                                                0.5
#
#    pipeline__featureunion__targetencoder__remainder__remainder__remainder__date_feature_week_cat  \
# 0                                           0.434946
#
#    pipeline__featureunion__targetencoder__remainder__remainder__remainder__date_feature_dayofYear_cat  \
# 0                                                0.5
#
#    pipeline__remainder__featureunion__cyclicalfeatures__remainder__remainder__date_feature_month_sin  \
# 0                                      -2.449294e-16
#
#    pipeline__remainder__featureunion__cyclicalfeatures__remainder__remainder__date_feature_month_cos  \
# 0                                                1.0
#
#    pipeline__remainder__featureunion__cyclicalfeatures__remainder__remainder__date_feature_day_sin  \
# 0                                      -2.449294e-16
#
#    pipeline__remainder__featureunion__cyclicalfeatures__remainder__remainder__date_feature_day_cos  \
# 0                                                1.0
#
#    pipeline__remainder__featureunion__cyclicalfeatures__remainder__remainder__date_feature_dayofweek_sin  \
# 0                                          -0.866025
#
#    pipeline__remainder__featureunion__cyclicalfeatures__remainder__remainder__date_feature_dayofweek_cos  \
# 0                                                0.5
#
#    pipeline__remainder__featureunion__cyclicalfeatures__remainder__remainder__date_feature_week_sin  \
# 0                                            0.98904
#
#    pipeline__remainder__featureunion__cyclicalfeatures__remainder__remainder__date_feature_week_cos  \
# 0                                           0.147647
#
#    pipeline__remainder__featureunion__cyclicalfeatures__remainder__remainder__date_feature_dayofYear_sin  \
# 0                                           0.072995
#
#    pipeline__remainder__featureunion__cyclicalfeatures__remainder__remainder__date_feature_dayofYear_cos  \
# 0                                           0.997332
#
#    remainder__pipeline__targetencoder__remainder__cat_feature1  \
# 0                                           0.570926
#
#    remainder__pipeline__targetencoder__remainder__cat_feature2  \
# 0                                           0.570926
#
#    remainder__remainder__pipeline__standardscaler__num_feature1  \
# 0                                           2.236068
#
#    remainder__remainder__pipeline__standardscaler__num_feature2
# 0                                           2.236068
# /home/maxime/Documents/WORKSPACES/forecasting_models/.venv/lib/python3.10/site-packages/category_encoders/ordinal.py:198: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   X[column] = X[column].astype("object").fillna(np.nan).map(col_mapping)
# /home/maxime/Documents/WORKSPACES/forecasting_models/.venv/lib/python3.10/site-packages/category_encoders/ordinal.py:198: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   X[column] = X[column].astype("object").fillna(np.nan).map(col_mapping)
# /home/maxime/Documents/WORKSPACES/forecasting_models/.venv/lib/python3.10/site-packages/category_encoders/ordinal.py:198: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   X[column] = X[column].astype("object").fillna(np.nan).map(col_mapping)
# /home/maxime/Documents/WORKSPACES/forecasting_models/.venv/lib/python3.10/site-packages/category_encoders/ordinal.py:198: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   X[column] = X[column].astype("object").fillna(np.nan).map(col_mapping)
# /home/maxime/Documents/WORKSPACES/forecasting_models/.venv/lib/python3.10/site-packages/category_encoders/ordinal.py:198: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   X[column] = X[column].astype("object").fillna(np.nan).map(col_mapping)
