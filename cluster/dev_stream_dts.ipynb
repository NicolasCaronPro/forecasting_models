# %% [markdown]
# # Stream Dataset

# %%
import os
import sys
sys.path.insert(0, os.path.abspath(
    os.path.join(os.path.dirname('__file__'), '..')))

# %%
from src.encoding.encoders import *
from src.encoding.tools import create_encoding_pipeline
from src.models.sklearn_api_model import save_object, Model
from src.models.sklearn_api_models_config import get_model
from src.datasets.base_tabular_dataset import BaseTabularDataset
from src.experiments.base_experiment import BaseExperiment
import src.features as ft
import logging
import pandas as pd
import pathlib
import numpy as np
from datetime import datetime as dt
from src.location.location import Location
from statsmodels.tsa.arima.model import ARIMA
from statsmodels.tsa.statespace.sarimax import SARIMAX
import matplotlib.pyplot as plt
import warnings; warnings.simplefilter('ignore')
from sklearn.metrics import mean_absolute_error, mean_squared_error
from pmdarima import auto_arima

# %%
# Define the root directory of the project
root_dir = os.path.abspath(os.path.join(os.path.dirname('__file__'), '..'))
root_dir = pathlib.Path(root_dir)

# %%
# Define a logger used by all modules
logger = logging.getLogger()
logger.setLevel(logging.INFO)
logging.basicConfig(level=logging.INFO, encoding="utf-8",
                    format="%(name)s %(asctime)s: %(levelname)s: %(message)s", handlers=[logging.StreamHandler()])

# %% [markdown]
# ## Load dataset

# %%
ETABS = ['CHU Dijon'] # ['CHU Dijon', 'CH Beaune', 'CH Semur', 'CH Chatillon Montbard', 'CH privé Dijon']
DATE_START = '01-01-2019'
DATE_END = '06-12-2020'

# %%
# Select the features to be used in the dataset
ars_features_class = [
    ft.HospitalFeatures(include_emmergency_arrivals=True, include_nb_hospit=False),
    ft.AirQualityFeatures,
    ft.GoogleTrendFeatures,
    ft.MeteorologicalFeatures,
    ft.SociologicalFeatures,
    ft.PopulationFeatures,
    ft.SportsCompetitionFeatures,
    ft.TrafficFeatures,
    ft.EpidemiologicalFeatures
    ]

# %%
# Define the configuration for the fetching of the data
fetch_config = {
    "data_start": DATE_START,
    "data_stop": DATE_END,
    'data_dir': root_dir / 'data',
    "locations": ETABS
    }

# %%
# Select the target columns to be predicted
target_columns = ['nb_emmergencies']
# target_columns = ['nb_vers_hospit']
# target_columns = ['Y75T79']

# %%
# Define an encoding scheme to create the encoding pipeline
encoders_dict = {
    'number': {
        'as_number': {
            'imputers': [imputers.SimpleImputer(strategy='mean')],
            'encoders': [
                ne.StandardScaler(),
            ]
        }
    },
    'category': {
        'as_category': {
            'imputers': [imputers.SimpleImputer(strategy='most_frequent')],
            'encoders': [
                ne.MultiTargetEncoder(drop_invariant=True, return_df=True),
            ]
        }
    },
    'datetime': {
        'as_number': {
            'imputers': [de.DateFeatureExtractor()],
            'encoders': [
                ne.CyclicalFeatures(drop_original=True)
            ]
        },
        'as_category': {
            'imputers': [de.DateFeatureExtractor(dtype='category')],
            'encoders': [
                ne.MultiTargetEncoder(drop_invariant=True, return_df=True),
            ]
        }
    },
    'boolean': {
        'as_number': {
            'imputers': [imputers.SimpleImputer(strategy='most_frequent')],
             'encoders': [ne.BooleanEncoder()]
         }

    }
}

# %%
# Create the encoding pipeline
pipeline = create_encoding_pipeline(encoders_dict)
# Out:
# Creating encoding pipeline

# %%
pipeline
# Out:
# ColumnTransformer(remainder='passthrough',
#                   transformers=[('pipeline-1',
#                                  Pipeline(steps=[('featureunion-1',
#                                                   FeatureUnion(transformer_list=[('simpleimputer',
#                                                                                   SimpleImputer())])),
#                                                  ('featureunion-2',
#                                                   FeatureUnion(transformer_list=[('standardscaler',
#                                                                                   StandardScaler())]))]),
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x147fdfd60>),
#                                 ('pipelin...
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x147fdfd90>),
#                                 ('pipeline-5',
#                                  Pipeline(steps=[('featureunion-1',
#                                                   FeatureUnion(transformer_list=[('simpleimputer',
#                                                                                   SimpleImputer(strategy='most_frequent'))])),
#                                                  ('featureunion-2',
#                                                   FeatureUnion(transformer_list=[('booleanencoder',
#                                                                                   BooleanEncoder())]))]),
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x14800ebf0>)],
#                   verbose=True)

# %%
# Define the splitting scheme to create the sets
split_config = {'test_size': 0.2, 'val_size': 0.2, 'shuffle': False}

# %%
# Define the configuration of the dataset
dataset_config = {
    'from_date': DATE_START,
    'to_date': DATE_END,
    'locations': ETABS,
    'axis': 'rows',
    'shift': range(1, 8, 1),
    'rolling_window': [7, 14, 31, 365],
    'freq': '1D',
    'split_config': split_config,
    'create_X_y': True,
    'encoding_pipeline': pipeline,
    'targets_names': target_columns,
    'targets_shift': -1,
    'targets_rolling_window': 0,
    'targets_history_shifts': range(1, 8, 1),
    'targets_history_rolling_windows': [7, 14, 31, 365],
    'targets_locations': ['CHU Dijon'],
    'drop_constant_thr': 1.0,
    'data_dir': root_dir / 'data'
    }

# %%
# Create the dataset and fetch the data from the source then call get_dataset() method to fill the different attributes (X and y) of the different sets, and their encodings
arsTabularDataset = BaseTabularDataset(features_classes=ars_features_class, logger=logger, fetch_config=fetch_config, getter_config=dataset_config)
# Out:
# root 2024-12-10 12:16:52,266: INFO: Initialisation de la classe BaseTabularDataset
# root 2024-12-10 12:16:52,302: INFO: Initialisation des features
# root 2024-12-10 12:16:52,309: INFO: Fetching dataset
# root 2024-12-10 12:16:52,311: INFO: Fetching data for hospitalfeatures at CHU Dijon
# hospitalfeatures 2024-12-10 12:16:52,640: INFO: hospitalfeatures's data already fetched for CHU Dijon
# root 2024-12-10 12:16:52,667: INFO: Fetching data for airqualityfeatures at CHU Dijon
# root 2024-12-10 12:16:52,851: INFO: airqualityfeatures's data already fetched for CHU Dijon
# root 2024-12-10 12:16:52,864: INFO: Fetching data for googletrendfeatures at CHU Dijon
# root 2024-12-10 12:16:53,026: INFO: googletrendfeatures's data already fetched for CHU Dijon
# root 2024-12-10 12:16:53,041: INFO: Fetching data for meteorologicalfeatures at CHU Dijon
# root 2024-12-10 12:16:53,211: INFO: meteorologicalfeatures's data already fetched for CHU Dijon
# root 2024-12-10 12:16:53,223: INFO: Fetching data for sociologicalfeatures at CHU Dijon
# root 2024-12-10 12:16:53,371: INFO: sociologicalfeatures's data already fetched for CHU Dijon
# root 2024-12-10 12:16:53,387: INFO: Fetching data for populationfeatures at CHU Dijon
# root 2024-12-10 12:16:53,592: INFO: populationfeatures's data already fetched for CHU Dijon
# root 2024-12-10 12:16:53,606: INFO: Fetching data for sportscompetitionfeatures at CHU Dijon
# root 2024-12-10 12:16:53,762: INFO: sportscompetitionfeatures's data already fetched for CHU Dijon
# root 2024-12-10 12:16:53,771: INFO: Fetching data for trafficfeatures at CHU Dijon
# root 2024-12-10 12:16:53,935: INFO: trafficfeatures's data already fetched for CHU Dijon
# root 2024-12-10 12:16:53,943: INFO: Fetching data for epidemiologicalfeatures at CHU Dijon
# root 2024-12-10 12:16:54,106: INFO: epidemiologicalfeatures's data already fetched for CHU Dijon
# root 2024-12-10 12:16:54,288: INFO: Getting the dataset from 01-01-2019 to 06-12-2020 for CHU Dijon
# hospitalfeatures 2024-12-10 12:16:54,459: INFO: Getting data for hospitalfeatures from 2019-01-01 00:00:00 to 2020-12-06 00:00:00, at a 1D frequency
# hospitalfeatures 2024-12-10 12:16:54,484: INFO: Augmentation des features...
# root 2024-12-10 12:16:54,515: INFO: Getting data for airqualityfeatures from 2019-01-01 00:00:00 to 2020-12-06 00:00:00, at a 1D frequency
# root 2024-12-10 12:16:54,542: INFO: Augmentation des features...
# root 2024-12-10 12:16:54,783: INFO: Getting data for googletrendfeatures from 2019-01-01 00:00:00 to 2020-12-06 00:00:00, at a 1D frequency
# root 2024-12-10 12:16:54,863: INFO: Augmentation des features...
# root 2024-12-10 12:16:55,992: INFO: Getting data for meteorologicalfeatures from 2019-01-01 00:00:00 to 2020-12-06 00:00:00, at a 1D frequency
# root 2024-12-10 12:16:56,013: INFO: Augmentation des features...
# root 2024-12-10 12:16:56,152: WARNING: Plage des indices des lignes contenant des NaN: DatetimeIndex(['2019-01-01', '2019-01-02', '2019-01-03', '2019-01-04',
#                '2019-01-05', '2019-01-06', '2019-01-07', '2019-01-08',
#                '2019-01-09', '2019-01-10',
#                ...
#                '2020-11-27', '2020-11-28', '2020-11-29', '2020-11-30',
#                '2020-12-01', '2020-12-02', '2020-12-03', '2020-12-04',
#                '2020-12-05', '2020-12-06'],
#               dtype='datetime64[ns]', name='date', length=706, freq=None)
# root 2024-12-10 12:16:56,155: WARNING: Colonnes contenant des NaN pour ces indices: ['meteo_station', 'meteo_station%%J-1', 'meteo_station%%J-2', 'meteo_station%%J-3', 'meteo_station%%J-4', 'meteo_station%%J-5', 'meteo_station%%J-6', 'meteo_station%%J-7']
# root 2024-12-10 12:16:56,156: INFO: Getting data for sociologicalfeatures from 2019-01-01 00:00:00 to 2020-12-06 00:00:00, at a 1D frequency
# root 2024-12-10 12:16:56,176: INFO: Augmentation des features...
# root 2024-12-10 12:16:56,273: INFO: Getting data for populationfeatures from 2019-01-01 00:00:00 to 2020-12-06 00:00:00, at a 1D frequency
# root 2024-12-10 12:16:56,317: INFO: Augmentation des features...
# root 2024-12-10 12:16:56,786: INFO: Getting data for sportscompetitionfeatures from 2019-01-01 00:00:00 to 2020-12-06 00:00:00, at a 1D frequency
# root 2024-12-10 12:16:56,793: INFO: Augmentation des features...
# root 2024-12-10 12:16:56,815: INFO: Getting data for trafficfeatures from 2019-01-01 00:00:00 to 2020-12-06 00:00:00, at a 1D frequency
# root 2024-12-10 12:16:56,822: INFO: Augmentation des features...
# root 2024-12-10 12:16:56,842: INFO: Getting data for epidemiologicalfeatures from 2019-01-01 00:00:00 to 2020-12-06 00:00:00, at a 1D frequency
# root 2024-12-10 12:16:56,853: INFO: Augmentation des features...
# root 2024-12-10 12:16:56,978: INFO: Creating the target columns as nb_emmergencies_CHU Dijon shifted by -1
# root 2024-12-10 12:16:56,981: INFO: Creating target history columns...
# root 2024-12-10 12:16:56,991: INFO: Rolling windows will start from 1 samples before to n days before this starting sample
# root 2024-12-10 12:16:57,047: INFO: Calculating train/val/test sets and encodings...
# Dropped 164 constant columns from both sets: {'trend_éruption cutanée', 'PM10_FR26094', 'inc_ira', 'NO2_FR26094', 'trend_mal de tête', 'trend_épilepsie', 'trend_palpitations', 'NO2_FR26010', 'trend_vomissements', 'trend_gastro-entérite', 'PM10_FR26010', 'trend_SOS médecin', 'PM25_FR26094'}
# X shape: (451, 1734), y shape: (451, 1)
# [ColumnTransformer] .... (1 of 6) Processing pipeline-1, total=   0.1s
# [ColumnTransformer] .... (2 of 6) Processing pipeline-2, total=   0.0s
# [ColumnTransformer] .... (3 of 6) Processing pipeline-3, total=   0.1s
# [ColumnTransformer] .... (4 of 6) Processing pipeline-4, total=   0.1s
# root 2024-12-10 12:16:59,468: INFO: 47 features not encoded (same unit as target)
# [ColumnTransformer] .... (5 of 6) Processing pipeline-5, total=   0.1s
# [ColumnTransformer] ..... (6 of 6) Processing remainder, total=   0.0s

# %%
df = arsTabularDataset.data
df.shape
# Out:
# (705, 1782)

# %%
df
# Out:
#             O3_FR26005%%J-3  trend_fièvre%%J-5  trend_douleur%%mean_31J  \
# date
# 2019-01-01             38.0                0.0                54.483871
# 2019-01-02             31.0                0.0                54.838710
# 2019-01-03             26.0                0.0                55.193548
# 2019-01-04             36.0                0.0                55.548387
# 2019-01-05             62.0                0.0                55.774194
# ...                     ...                ...                      ...
# 2020-12-01             16.0                0.0                51.000000
# 2020-12-02             26.0                0.0                52.354839
# 2020-12-03             24.0                0.0                53.193548
# 2020-12-04             22.0                0.0                52.903226
# 2020-12-05             20.0                0.0                52.709677
#
#             Y60T64%%mean_31J  meteo_pres%%J-7  meteo_snow%%J-3  \
# date
# 2019-01-01      33434.354839           1034.5              0.0
# 2019-01-02      33434.354839           1034.5              0.0
# 2019-01-03      33434.354839           1034.5              0.0
# 2019-01-04      33434.354839           1034.5              0.0
# 2019-01-05      33434.354839           1034.5              0.0
# ...                      ...              ...              ...
# 2020-12-01      33712.129032           1026.1              0.0
# 2020-12-02      33712.000000           1021.1              0.0
# 2020-12-03      33711.870968           1022.1              0.0
# 2020-12-04      33711.741935           1018.9              0.0
# 2020-12-05      33711.580645           1016.6              0.0
#
#             trend_entorse%%mean_7J  meteo_snow%%std_365J  \
# date
# 2019-01-01                     0.0              2.666901
# 2019-01-02                     0.0              2.666901
# 2019-01-03                     0.0              2.666901
# 2019-01-04                     0.0              2.666901
# 2019-01-05                     0.0              2.666901
# ...                            ...                   ...
# 2020-12-01                     0.0              0.000000
# 2020-12-02                     0.0              0.000000
# 2020-12-03                     0.0              0.000000
# 2020-12-04                     0.0              0.000000
# 2020-12-05                     0.0              0.000000
#
#             trend_médecin%%mean_31J  Y50T54%%std_7J  ...  \
# date                                                 ...
# 2019-01-01                 3.225806        0.899735  ...
# 2019-01-02                 3.225806        0.899735  ...
# 2019-01-03                 3.225806        0.899735  ...
# 2019-01-04                 2.387097        0.899735  ...
# 2019-01-05                 2.387097        0.899735  ...
# ...                             ...             ...  ...
# 2020-12-01                 2.096774        0.000000  ...
# 2020-12-02                 2.096774        0.000000  ...
# 2020-12-03                 2.096774        0.000000  ...
# 2020-12-04                 2.096774        0.000000  ...
# 2020-12-05                 1.709677        0.377964  ...
#
#             trend_infection cutanée  eveBankHolidays%%J-5  \
# date
# 2019-01-01                      0.0                 False
# 2019-01-02                      0.0                 False
# 2019-01-03                      0.0                 False
# 2019-01-04                      0.0                 False
# 2019-01-05                      0.0                 False
# ...                             ...                   ...
# 2020-12-01                      0.0                 False
# 2020-12-02                      0.0                 False
# 2020-12-03                     72.0                 False
# 2020-12-04                      0.0                 False
# 2020-12-05                      0.0                 False
#
#             trend_allergie%%J-3  Y_LT5%%J-2  trend_hypothermie%%J-7  \
# date
# 2019-01-01                  0.0     26662.0                     0.0
# 2019-01-02                  0.0     26662.0                     0.0
# 2019-01-03                  0.0     26662.0                     0.0
# 2019-01-04                  0.0     26660.0                     0.0
# 2019-01-05                  0.0     26659.0                     0.0
# ...                         ...         ...                     ...
# 2020-12-01                  0.0     26160.0                     0.0
# 2020-12-02                  0.0     26160.0                     0.0
# 2020-12-03                  0.0     26160.0                     0.0
# 2020-12-04                  0.0     26160.0                     0.0
# 2020-12-05                  0.0     26160.0                     0.0
#
#             trend_éruption cutanée%%J-6  trend_stress%%J-1  trend_noyade%%J-5  \
# date
# 2019-01-01                          0.0                0.0                0.0
# 2019-01-02                          0.0                0.0                0.0
# 2019-01-03                          0.0                0.0                0.0
# 2019-01-04                          0.0                0.0                0.0
# 2019-01-05                         84.0                0.0                0.0
# ...                                 ...                ...                ...
# 2020-12-01                          0.0                0.0                0.0
# 2020-12-02                          0.0                0.0                0.0
# 2020-12-03                          0.0                0.0                0.0
# 2020-12-04                          0.0                0.0                0.0
# 2020-12-05                          0.0                0.0                0.0
#
#             trend_douleur%%std_31J  trend_méningite%%mean_31J
# date
# 2019-01-01               25.015823                   2.225806
# 2019-01-02               25.246910                   2.225806
# 2019-01-03               25.268451                   2.225806
# 2019-01-04               25.400576                   2.225806
# 2019-01-05               25.472481                   2.225806
# ...                            ...                        ...
# 2020-12-01               16.769019                   0.000000
# 2020-12-02               13.975093                   0.000000
# 2020-12-03               13.739043                   0.000000
# 2020-12-04               13.597438                   0.000000
# 2020-12-05               13.609295                   0.000000
#
# [705 rows x 1782 columns]

# %%
col1 = df.columns

# %% [markdown]
# ## Update dataset

# %%
def update(dataset, date_to=None, steps=1):
    shift = abs(dataset.getter_config['targets_shift'])
    if date_to is None:
        date_to = (dataset.data.index[-1] + pd.Timedelta(days=steps+shift)).strftime('%d-%m-%Y')
    else:
        date_to = (dt.strptime(date_to, '%d-%m-%Y') + pd.Timedelta(days=shift)).strftime('%d-%m-%Y')
    dataset.getter_config['to_date'] = date_to
    dataset.fetch_config['data_stop'] = date_to
    dataset.fetch_dataset(**dataset.fetch_config)
    dataset.get_dataset(**dataset.getter_config, inplace=True)
    return dataset

# %% [markdown]
# ### Increment untill date

# %%
arsTabularDataset = update(arsTabularDataset, date_to='09-12-2024')
df = arsTabularDataset.data
# Out:
# root 2024-12-10 12:17:00,086: INFO: Fetching dataset
# root 2024-12-10 12:17:00,094: INFO: Fetching data for hospitalfeatures at CHU Dijon is located at Dijon, 21231, Côte-d'Or, Bourgogne-Franche-Comté
# hospitalfeatures 2024-12-10 12:17:00,100: INFO: hospitalfeatures's data already fetched for CHU Dijon
# root 2024-12-10 12:17:00,141: INFO: Fetching data for airqualityfeatures at CHU Dijon is located at Dijon, 21231, Côte-d'Or, Bourgogne-Franche-Comté
# root 2024-12-10 12:17:00,144: INFO: airqualityfeatures's data already fetched for CHU Dijon
# root 2024-12-10 12:17:00,163: INFO: Fetching data for googletrendfeatures at CHU Dijon is located at Dijon, 21231, Côte-d'Or, Bourgogne-Franche-Comté
# root 2024-12-10 12:17:00,165: INFO: googletrendfeatures's data already fetched for CHU Dijon
# root 2024-12-10 12:17:00,185: INFO: Fetching data for meteorologicalfeatures at CHU Dijon is located at Dijon, 21231, Côte-d'Or, Bourgogne-Franche-Comté
# root 2024-12-10 12:17:00,187: INFO: meteorologicalfeatures's data already fetched for CHU Dijon
# root 2024-12-10 12:17:00,196: WARNING: Updating data
# root 2024-12-10 12:17:01,034: INFO: Fetching data for sociologicalfeatures at CHU Dijon is located at Dijon, 21231, Côte-d'Or, Bourgogne-Franche-Comté
# root 2024-12-10 12:17:01,036: INFO: sociologicalfeatures's data already fetched for CHU Dijon
# root 2024-12-10 12:17:01,057: INFO: Fetching data for populationfeatures at CHU Dijon is located at Dijon, 21231, Côte-d'Or, Bourgogne-Franche-Comté
# root 2024-12-10 12:17:01,059: INFO: populationfeatures's data already fetched for CHU Dijon
# root 2024-12-10 12:17:01,071: INFO: Fetching data for sportscompetitionfeatures at CHU Dijon is located at Dijon, 21231, Côte-d'Or, Bourgogne-Franche-Comté
# root 2024-12-10 12:17:01,074: INFO: sportscompetitionfeatures's data already fetched for CHU Dijon
# root 2024-12-10 12:17:01,089: INFO: Fetching data for trafficfeatures at CHU Dijon is located at Dijon, 21231, Côte-d'Or, Bourgogne-Franche-Comté
# root 2024-12-10 12:17:01,090: INFO: trafficfeatures's data already fetched for CHU Dijon
# root 2024-12-10 12:17:01,100: INFO: Fetching data for epidemiologicalfeatures at CHU Dijon is located at Dijon, 21231, Côte-d'Or, Bourgogne-Franche-Comté
# root 2024-12-10 12:17:01,102: INFO: epidemiologicalfeatures's data already fetched for CHU Dijon
# root 2024-12-10 12:17:01,113: INFO: Getting the dataset from 01-01-2019 to 10-12-2024 for CHU Dijon
# hospitalfeatures 2024-12-10 12:17:01,115: INFO: Getting data for hospitalfeatures from 2019-01-01 00:00:00 to 2024-12-10 00:00:00, at a 1D frequency
# hospitalfeatures 2024-12-10 12:17:01,136: INFO: Augmentation des features...
# root 2024-12-10 12:17:01,167: INFO: Getting data for airqualityfeatures from 2019-01-01 00:00:00 to 2024-12-10 00:00:00, at a 1D frequency
# root 2024-12-10 12:17:01,223: INFO: Augmentation des features...
# root 2024-12-10 12:17:01,534: INFO: Getting data for googletrendfeatures from 2019-01-01 00:00:00 to 2024-12-10 00:00:00, at a 1D frequency
# root 2024-12-10 12:17:01,616: INFO: Augmentation des features...
# root 2024-12-10 12:17:02,672: INFO: Getting data for meteorologicalfeatures from 2019-01-01 00:00:00 to 2024-12-10 00:00:00, at a 1D frequency
# root 2024-12-10 12:17:02,690: INFO: Augmentation des features...
# root 2024-12-10 12:17:02,811: WARNING: Plage des indices des lignes contenant des NaN: DatetimeIndex(['2019-01-01', '2019-01-02', '2019-01-03', '2019-01-04',
#                '2019-01-05', '2019-01-06', '2019-01-07', '2019-01-08',
#                '2019-01-09', '2019-01-10',
#                ...
#                '2024-12-01', '2024-12-02', '2024-12-03', '2024-12-04',
#                '2024-12-05', '2024-12-06', '2024-12-07', '2024-12-08',
#                '2024-12-09', '2024-12-10'],
#               dtype='datetime64[ns]', name='date', length=2171, freq=None)
# root 2024-12-10 12:17:02,814: WARNING: Colonnes contenant des NaN pour ces indices: ['meteo_station', 'meteo_station%%J-1', 'meteo_station%%J-2', 'meteo_station%%J-3', 'meteo_station%%J-4', 'meteo_station%%J-5', 'meteo_station%%J-6', 'meteo_station%%J-7']
# root 2024-12-10 12:17:02,815: INFO: Getting data for sociologicalfeatures from 2019-01-01 00:00:00 to 2024-12-10 00:00:00, at a 1D frequency
# root 2024-12-10 12:17:02,830: INFO: Augmentation des features...
# root 2024-12-10 12:17:02,948: WARNING: Plage des indices des lignes contenant des NaN: DatetimeIndex(['2023-12-31', '2024-01-01', '2024-01-02', '2024-01-03',
#                '2024-01-04', '2024-01-05', '2024-01-06', '2024-01-07'],
#               dtype='datetime64[ns]', name='date', freq=None)
# root 2024-12-10 12:17:02,954: WARNING: Colonnes contenant des NaN pour ces indices: ['borderHolidays', 'borderHolidays%%J-1', 'borderHolidays%%J-2', 'borderHolidays%%J-3', 'borderHolidays%%J-4', 'borderHolidays%%J-5', 'borderHolidays%%J-6', 'borderHolidays%%J-7']
# root 2024-12-10 12:17:02,955: INFO: Getting data for populationfeatures from 2019-01-01 00:00:00 to 2024-12-10 00:00:00, at a 1D frequency
# root 2024-12-10 12:17:02,999: INFO: Augmentation des features...
# root 2024-12-10 12:17:03,432: INFO: Getting data for sportscompetitionfeatures from 2019-01-01 00:00:00 to 2024-12-10 00:00:00, at a 1D frequency
# root 2024-12-10 12:17:03,440: INFO: Augmentation des features...
# root 2024-12-10 12:17:03,461: INFO: Getting data for trafficfeatures from 2019-01-01 00:00:00 to 2024-12-10 00:00:00, at a 1D frequency
# root 2024-12-10 12:17:03,472: INFO: Augmentation des features...
# root 2024-12-10 12:17:03,490: INFO: Getting data for epidemiologicalfeatures from 2019-01-01 00:00:00 to 2024-12-10 00:00:00, at a 1D frequency
# root 2024-12-10 12:17:03,507: INFO: Augmentation des features...
# root 2024-12-10 12:17:03,834: INFO: Creating the target columns as nb_emmergencies_CHU Dijon shifted by -1
# root 2024-12-10 12:17:03,837: INFO: Creating target history columns...
# root 2024-12-10 12:17:03,851: INFO: Rolling windows will start from 1 samples before to n days before this starting sample
# root 2024-12-10 12:17:03,926: INFO: Calculating train/val/test sets and encodings...
# Dropped 90 constant columns from both sets: {'PM10_FR26094', 'NO2_FR26094', 'trend_épilepsie', 'NO2_FR26010', 'PM10_FR26010', 'PM25_FR26094'}
# X shape: (1388, 1808), y shape: (1388, 1)
# [ColumnTransformer] .... (1 of 6) Processing pipeline-1, total=   0.2s
# [ColumnTransformer] .... (2 of 6) Processing pipeline-2, total=   0.0s
# [ColumnTransformer] .... (3 of 6) Processing pipeline-3, total=   0.0s
# [ColumnTransformer] .... (4 of 6) Processing pipeline-4, total=   0.1s
# root 2024-12-10 12:17:05,771: INFO: 47 features not encoded (same unit as target)
# [ColumnTransformer] .... (5 of 6) Processing pipeline-5, total=   0.1s
# [ColumnTransformer] ..... (6 of 6) Processing remainder, total=   0.0s

# %%
df
# Out:
#             O3_FR26005%%J-3  trend_fièvre%%J-5  trend_douleur%%mean_31J  \
# 2019-01-01             38.0                0.0                54.483871
# 2019-01-02             31.0                0.0                54.838710
# 2019-01-03             26.0                0.0                55.193548
# 2019-01-04             36.0                0.0                55.548387
# 2019-01-05             62.0                0.0                55.774194
# ...                     ...                ...                      ...
# 2024-12-05             58.0                0.0                79.000000
# 2024-12-06             58.0                0.0                79.000000
# 2024-12-07             58.0                0.0                79.000000
# 2024-12-08             58.0                0.0                79.000000
# 2024-12-09             58.0                0.0                79.000000
#
#             Y60T64%%mean_31J  meteo_pres%%J-7  meteo_snow%%J-3  \
# 2019-01-01      33434.354839           1034.5              0.0
# 2019-01-02      33434.354839           1034.5              0.0
# 2019-01-03      33434.354839           1034.5              0.0
# 2019-01-04      33434.354839           1034.5              0.0
# 2019-01-05      33434.354839           1034.5              0.0
# ...                      ...              ...              ...
# 2024-12-05      33749.000000           1026.1              0.0
# 2024-12-06      33749.000000           1028.8              0.0
# 2024-12-07      33749.000000           1029.2              0.0
# 2024-12-08      33749.000000           1024.9              0.0
# 2024-12-09      33749.000000           1019.8              0.0
#
#             trend_entorse%%mean_7J  meteo_snow%%std_365J  \
# 2019-01-01                     0.0              2.666901
# 2019-01-02                     0.0              2.666901
# 2019-01-03                     0.0              2.666901
# 2019-01-04                     0.0              2.666901
# 2019-01-05                     0.0              2.666901
# ...                            ...                   ...
# 2024-12-05                     0.0             22.617892
# 2024-12-06                     0.0             22.617892
# 2024-12-07                     0.0             22.617892
# 2024-12-08                     0.0             22.617892
# 2024-12-09                     0.0             22.617892
#
#             trend_médecin%%mean_31J  Y50T54%%std_7J  ...  \
# 2019-01-01                 3.225806        0.899735  ...
# 2019-01-02                 3.225806        0.899735  ...
# 2019-01-03                 3.225806        0.899735  ...
# 2019-01-04                 2.387097        0.899735  ...
# 2019-01-05                 2.387097        0.899735  ...
# ...                             ...             ...  ...
# 2024-12-05                16.000000        0.000000  ...
# 2024-12-06                16.000000        0.000000  ...
# 2024-12-07                16.000000        0.000000  ...
# 2024-12-08                16.000000        0.000000  ...
# 2024-12-09                16.000000        0.000000  ...
#
#             eveBankHolidays%%J-5  trend_allergie%%J-3  Y_LT5%%J-2  \
# 2019-01-01                 False                  0.0     26662.0
# 2019-01-02                 False                  0.0     26662.0
# 2019-01-03                 False                  0.0     26662.0
# 2019-01-04                 False                  0.0     26660.0
# 2019-01-05                 False                  0.0     26659.0
# ...                          ...                  ...         ...
# 2024-12-05                 False                  0.0     24333.0
# 2024-12-06                 False                  0.0     24333.0
# 2024-12-07                 False                  0.0     24333.0
# 2024-12-08                 False                  0.0     24333.0
# 2024-12-09                 False                  0.0     24333.0
#
#             trend_hypothermie%%J-7  trend_éruption cutanée%%J-6  \
# 2019-01-01                     0.0                          0.0
# 2019-01-02                     0.0                          0.0
# 2019-01-03                     0.0                          0.0
# 2019-01-04                     0.0                          0.0
# 2019-01-05                     0.0                         84.0
# ...                            ...                          ...
# 2024-12-05                     0.0                          0.0
# 2024-12-06                     0.0                          0.0
# 2024-12-07                     0.0                          0.0
# 2024-12-08                     0.0                          0.0
# 2024-12-09                     0.0                          0.0
#
#             trend_stress%%J-1  trend_noyade%%J-5  inc_ira%%J-7  \
# 2019-01-01                0.0                0.0           0.0
# 2019-01-02                0.0                0.0           0.0
# 2019-01-03                0.0                0.0           0.0
# 2019-01-04                0.0                0.0           0.0
# 2019-01-05                0.0                0.0           0.0
# ...                       ...                ...           ...
# 2024-12-05                0.0                0.0        6291.0
# 2024-12-06                0.0                0.0        6291.0
# 2024-12-07                0.0                0.0        6291.0
# 2024-12-08                0.0                0.0        6291.0
# 2024-12-09                0.0                0.0        6291.0
#
#             trend_douleur%%std_31J  trend_méningite%%mean_31J
# 2019-01-01               25.015823                   2.225806
# 2019-01-02               25.246910                   2.225806
# 2019-01-03               25.268451                   2.225806
# 2019-01-04               25.400576                   2.225806
# 2019-01-05               25.472481                   2.225806
# ...                            ...                        ...
# 2024-12-05                0.000000                   0.000000
# 2024-12-06                0.000000                   0.000000
# 2024-12-07                0.000000                   0.000000
# 2024-12-08                0.000000                   0.000000
# 2024-12-09                0.000000                   0.000000
#
# [2170 rows x 1856 columns]

# %%
print([i for i in df.columns if i not in col1])
# Out:
# ['trend_palpitations%%J-6', 'trend_palpitations%%J-2', 'trend_SOS médecin%%J-7', 'trend_gastro-entérite%%J-1', 'trend_mal de tête%%std_14J', 'trend_mal de tête%%J-5', 'trend_SOS médecin%%J-2', 'trend_SOS médecin%%mean_7J', 'trend_gastro-entérite%%J-2', 'trend_vomissements%%mean_7J', 'trend_mal de tête%%std_31J', 'trend_vomissements%%J-6', 'trend_vomissements%%J-3', 'trend_vomissements%%J-4', 'trend_vomissements%%J-2', 'trend_gastro-entérite%%J-6', 'trend_SOS médecin%%mean_31J', 'trend_gastro-entérite%%std_7J', 'trend_SOS médecin%%std_31J', 'trend_mal de tête%%J-1', 'trend_SOS médecin%%J-3', 'trend_gastro-entérite%%mean_31J', 'trend_gastro-entérite%%J-3', 'trend_mal de tête%%J-3', 'trend_vomissements', 'trend_vomissements%%J-5', 'trend_vomissements%%mean_14J', 'trend_SOS médecin%%J-5', 'trend_SOS médecin%%std_14J', 'trend_mal de tête', 'trend_vomissements%%std_14J', 'inc_ira%%J-6', 'trend_mal de tête%%J-7', 'trend_SOS médecin%%J-4', 'trend_vomissements%%std_31J', 'trend_gastro-entérite%%std_14J', 'inc_ira%%J-4', 'trend_mal de tête%%J-6', 'trend_SOS médecin%%mean_14J', 'trend_mal de tête%%mean_31J', 'trend_mal de tête%%std_7J', 'inc_ira%%J-5', 'trend_palpitations%%J-7', 'trend_SOS médecin%%std_7J', 'trend_gastro-entérite%%mean_7J', 'trend_SOS médecin%%J-6', 'trend_SOS médecin%%J-1', 'trend_palpitations%%std_14J', 'trend_palpitations', 'trend_vomissements%%J-7', 'trend_vomissements%%std_7J', 'trend_gastro-entérite%%J-5', 'trend_palpitations%%mean_7J', 'trend_palpitations%%J-3', 'trend_palpitations%%mean_14J', 'trend_SOS médecin', 'trend_mal de tête%%mean_7J', 'trend_vomissements%%J-1', 'None', 'trend_vomissements%%mean_31J', 'trend_mal de tête%%J-2', 'trend_mal de tête%%mean_14J', 'trend_éruption cutanée%%J-1', 'trend_palpitations%%J-4', 'trend_éruption cutanée', 'trend_gastro-entérite%%J-4', 'trend_gastro-entérite%%J-7', 'trend_gastro-entérite', 'trend_mal de tête%%J-4', 'trend_palpitations%%J-1', 'trend_gastro-entérite%%std_31J', 'trend_gastro-entérite%%mean_14J', 'trend_palpitations%%std_7J', 'trend_palpitations%%J-5', 'inc_ira%%J-7']

# %%
print([i for i in col1 if i not in df.columns])
# Out:
# ['date']

# %% [markdown]
# ### Increment by 1 day

# %%
arsTabularDataset = update(arsTabularDataset)
df = arsTabularDataset.data
df.shape
# Out:
# root 2024-12-10 12:17:06,484: INFO: Fetching dataset
# root 2024-12-10 12:17:06,486: INFO: Fetching data for hospitalfeatures at CHU Dijon is located at Dijon, 21231, Côte-d'Or, Bourgogne-Franche-Comté
# hospitalfeatures 2024-12-10 12:17:06,492: INFO: hospitalfeatures's data already fetched for CHU Dijon
# root 2024-12-10 12:17:06,509: INFO: Fetching data for airqualityfeatures at CHU Dijon is located at Dijon, 21231, Côte-d'Or, Bourgogne-Franche-Comté
# root 2024-12-10 12:17:06,512: INFO: airqualityfeatures's data already fetched for CHU Dijon
# root 2024-12-10 12:17:06,530: INFO: Fetching data for googletrendfeatures at CHU Dijon is located at Dijon, 21231, Côte-d'Or, Bourgogne-Franche-Comté
# root 2024-12-10 12:17:06,532: INFO: googletrendfeatures's data already fetched for CHU Dijon
# root 2024-12-10 12:17:06,549: INFO: Fetching data for meteorologicalfeatures at CHU Dijon is located at Dijon, 21231, Côte-d'Or, Bourgogne-Franche-Comté
# root 2024-12-10 12:17:06,550: INFO: meteorologicalfeatures's data already fetched for CHU Dijon
# root 2024-12-10 12:17:06,559: WARNING: Updating data
# root 2024-12-10 12:17:06,654: INFO: Fetching data for sociologicalfeatures at CHU Dijon is located at Dijon, 21231, Côte-d'Or, Bourgogne-Franche-Comté
# root 2024-12-10 12:17:06,657: INFO: sociologicalfeatures's data already fetched for CHU Dijon
# root 2024-12-10 12:17:06,680: INFO: Fetching data for populationfeatures at CHU Dijon is located at Dijon, 21231, Côte-d'Or, Bourgogne-Franche-Comté
# root 2024-12-10 12:17:06,681: INFO: populationfeatures's data already fetched for CHU Dijon
# root 2024-12-10 12:17:06,698: INFO: Fetching data for sportscompetitionfeatures at CHU Dijon is located at Dijon, 21231, Côte-d'Or, Bourgogne-Franche-Comté
# root 2024-12-10 12:17:06,699: INFO: sportscompetitionfeatures's data already fetched for CHU Dijon
# root 2024-12-10 12:17:06,714: INFO: Fetching data for trafficfeatures at CHU Dijon is located at Dijon, 21231, Côte-d'Or, Bourgogne-Franche-Comté
# root 2024-12-10 12:17:06,716: INFO: trafficfeatures's data already fetched for CHU Dijon
# root 2024-12-10 12:17:06,728: INFO: Fetching data for epidemiologicalfeatures at CHU Dijon is located at Dijon, 21231, Côte-d'Or, Bourgogne-Franche-Comté
# root 2024-12-10 12:17:06,731: INFO: epidemiologicalfeatures's data already fetched for CHU Dijon
# root 2024-12-10 12:17:06,832: INFO: Getting the dataset from 01-01-2019 to 11-12-2024 for CHU Dijon
# hospitalfeatures 2024-12-10 12:17:06,841: INFO: Getting data for hospitalfeatures from 2019-01-01 00:00:00 to 2024-12-11 00:00:00, at a 1D frequency
# hospitalfeatures 2024-12-10 12:17:06,859: INFO: Augmentation des features...
# root 2024-12-10 12:17:06,890: INFO: Getting data for airqualityfeatures from 2019-01-01 00:00:00 to 2024-12-11 00:00:00, at a 1D frequency
# root 2024-12-10 12:17:06,940: INFO: Augmentation des features...
# root 2024-12-10 12:17:07,214: INFO: Getting data for googletrendfeatures from 2019-01-01 00:00:00 to 2024-12-11 00:00:00, at a 1D frequency
# root 2024-12-10 12:17:07,303: INFO: Augmentation des features...
# root 2024-12-10 12:17:08,613: INFO: Getting data for meteorologicalfeatures from 2019-01-01 00:00:00 to 2024-12-11 00:00:00, at a 1D frequency
# root 2024-12-10 12:17:08,634: INFO: Augmentation des features...
# root 2024-12-10 12:17:08,783: WARNING: Plage des indices des lignes contenant des NaN: DatetimeIndex(['2019-01-01', '2019-01-02', '2019-01-03', '2019-01-04',
#                '2019-01-05', '2019-01-06', '2019-01-07', '2019-01-08',
#                '2019-01-09', '2019-01-10',
#                ...
#                '2024-12-01', '2024-12-02', '2024-12-03', '2024-12-04',
#                '2024-12-05', '2024-12-06', '2024-12-07', '2024-12-08',
#                '2024-12-09', '2024-12-10'],
#               dtype='datetime64[ns]', name='date', length=2171, freq=None)
# root 2024-12-10 12:17:08,786: WARNING: Colonnes contenant des NaN pour ces indices: ['meteo_station', 'meteo_station%%J-1', 'meteo_station%%J-2', 'meteo_station%%J-3', 'meteo_station%%J-4', 'meteo_station%%J-5', 'meteo_station%%J-6', 'meteo_station%%J-7']
# root 2024-12-10 12:17:08,787: INFO: Getting data for sociologicalfeatures from 2019-01-01 00:00:00 to 2024-12-11 00:00:00, at a 1D frequency
# root 2024-12-10 12:17:08,808: INFO: Augmentation des features...
# root 2024-12-10 12:17:08,949: WARNING: Plage des indices des lignes contenant des NaN: DatetimeIndex(['2023-12-31', '2024-01-01', '2024-01-02', '2024-01-03',
#                '2024-01-04', '2024-01-05', '2024-01-06', '2024-01-07'],
#               dtype='datetime64[ns]', name='date', freq=None)
# root 2024-12-10 12:17:08,955: WARNING: Colonnes contenant des NaN pour ces indices: ['borderHolidays', 'borderHolidays%%J-1', 'borderHolidays%%J-2', 'borderHolidays%%J-3', 'borderHolidays%%J-4', 'borderHolidays%%J-5', 'borderHolidays%%J-6', 'borderHolidays%%J-7']
# root 2024-12-10 12:17:08,957: INFO: Getting data for populationfeatures from 2019-01-01 00:00:00 to 2024-12-11 00:00:00, at a 1D frequency
# root 2024-12-10 12:17:09,009: INFO: Augmentation des features...
# root 2024-12-10 12:17:09,418: INFO: Getting data for sportscompetitionfeatures from 2019-01-01 00:00:00 to 2024-12-11 00:00:00, at a 1D frequency
# root 2024-12-10 12:17:09,426: INFO: Augmentation des features...
# root 2024-12-10 12:17:09,444: INFO: Getting data for trafficfeatures from 2019-01-01 00:00:00 to 2024-12-11 00:00:00, at a 1D frequency
# root 2024-12-10 12:17:09,451: INFO: Augmentation des features...
# root 2024-12-10 12:17:09,469: INFO: Getting data for epidemiologicalfeatures from 2019-01-01 00:00:00 to 2024-12-11 00:00:00, at a 1D frequency
# root 2024-12-10 12:17:09,486: INFO: Augmentation des features...
# root 2024-12-10 12:17:09,722: INFO: Creating the target columns as nb_emmergencies_CHU Dijon shifted by -1
# root 2024-12-10 12:17:09,724: INFO: Creating target history columns...
# root 2024-12-10 12:17:09,735: INFO: Rolling windows will start from 1 samples before to n days before this starting sample
# root 2024-12-10 12:17:09,803: INFO: Calculating train/val/test sets and encodings...
# Dropped 90 constant columns from both sets: {'PM10_FR26094', 'NO2_FR26094', 'trend_épilepsie', 'NO2_FR26010', 'PM10_FR26010', 'PM25_FR26094'}
# X shape: (1388, 1808), y shape: (1388, 1)
# [ColumnTransformer] .... (1 of 6) Processing pipeline-1, total=   0.1s
# [ColumnTransformer] .... (2 of 6) Processing pipeline-2, total=   0.0s
# [ColumnTransformer] .... (3 of 6) Processing pipeline-3, total=   0.0s
# [ColumnTransformer] .... (4 of 6) Processing pipeline-4, total=   0.1s
# root 2024-12-10 12:17:11,488: INFO: 47 features not encoded (same unit as target)
# [ColumnTransformer] .... (5 of 6) Processing pipeline-5, total=   0.1s
# [ColumnTransformer] ..... (6 of 6) Processing remainder, total=   0.0s
# (2171, 1856)

# %%
df
# Out:
#             O3_FR26005%%J-3  trend_fièvre%%J-5  trend_douleur%%mean_31J  \
# 2019-01-01             38.0                0.0                54.483871
# 2019-01-02             31.0                0.0                54.838710
# 2019-01-03             26.0                0.0                55.193548
# 2019-01-04             36.0                0.0                55.548387
# 2019-01-05             62.0                0.0                55.774194
# ...                     ...                ...                      ...
# 2024-12-06             58.0                0.0                79.000000
# 2024-12-07             58.0                0.0                79.000000
# 2024-12-08             58.0                0.0                79.000000
# 2024-12-09             58.0                0.0                79.000000
# 2024-12-10             58.0                0.0                79.000000
#
#             Y60T64%%mean_31J  meteo_pres%%J-7  meteo_snow%%J-3  \
# 2019-01-01      33434.354839           1034.5              0.0
# 2019-01-02      33434.354839           1034.5              0.0
# 2019-01-03      33434.354839           1034.5              0.0
# 2019-01-04      33434.354839           1034.5              0.0
# 2019-01-05      33434.354839           1034.5              0.0
# ...                      ...              ...              ...
# 2024-12-06      33749.000000           1028.8              0.0
# 2024-12-07      33749.000000           1029.2              0.0
# 2024-12-08      33749.000000           1024.9              0.0
# 2024-12-09      33749.000000           1019.8              0.0
# 2024-12-10      33749.000000           1021.7              0.0
#
#             trend_entorse%%mean_7J  meteo_snow%%std_365J  \
# 2019-01-01                     0.0              2.666901
# 2019-01-02                     0.0              2.666901
# 2019-01-03                     0.0              2.666901
# 2019-01-04                     0.0              2.666901
# 2019-01-05                     0.0              2.666901
# ...                            ...                   ...
# 2024-12-06                     0.0             22.617892
# 2024-12-07                     0.0             22.617892
# 2024-12-08                     0.0             22.617892
# 2024-12-09                     0.0             22.617892
# 2024-12-10                     0.0             22.617892
#
#             trend_médecin%%mean_31J  Y50T54%%std_7J  ...  \
# 2019-01-01                 3.225806        0.899735  ...
# 2019-01-02                 3.225806        0.899735  ...
# 2019-01-03                 3.225806        0.899735  ...
# 2019-01-04                 2.387097        0.899735  ...
# 2019-01-05                 2.387097        0.899735  ...
# ...                             ...             ...  ...
# 2024-12-06                16.000000        0.000000  ...
# 2024-12-07                16.000000        0.000000  ...
# 2024-12-08                16.000000        0.000000  ...
# 2024-12-09                16.000000        0.000000  ...
# 2024-12-10                16.000000        0.000000  ...
#
#             eveBankHolidays%%J-5  trend_allergie%%J-3  Y_LT5%%J-2  \
# 2019-01-01                 False                  0.0     26662.0
# 2019-01-02                 False                  0.0     26662.0
# 2019-01-03                 False                  0.0     26662.0
# 2019-01-04                 False                  0.0     26660.0
# 2019-01-05                 False                  0.0     26659.0
# ...                          ...                  ...         ...
# 2024-12-06                 False                  0.0     24333.0
# 2024-12-07                 False                  0.0     24333.0
# 2024-12-08                 False                  0.0     24333.0
# 2024-12-09                 False                  0.0     24333.0
# 2024-12-10                 False                  0.0     24333.0
#
#             trend_hypothermie%%J-7  trend_éruption cutanée%%J-6  \
# 2019-01-01                     0.0                          0.0
# 2019-01-02                     0.0                          0.0
# 2019-01-03                     0.0                          0.0
# 2019-01-04                     0.0                          0.0
# 2019-01-05                     0.0                         84.0
# ...                            ...                          ...
# 2024-12-06                     0.0                          0.0
# 2024-12-07                     0.0                          0.0
# 2024-12-08                     0.0                          0.0
# 2024-12-09                     0.0                          0.0
# 2024-12-10                     0.0                          0.0
#
#             trend_stress%%J-1  trend_noyade%%J-5  inc_ira%%J-7  \
# 2019-01-01                0.0                0.0           0.0
# 2019-01-02                0.0                0.0           0.0
# 2019-01-03                0.0                0.0           0.0
# 2019-01-04                0.0                0.0           0.0
# 2019-01-05                0.0                0.0           0.0
# ...                       ...                ...           ...
# 2024-12-06                0.0                0.0        6291.0
# 2024-12-07                0.0                0.0        6291.0
# 2024-12-08                0.0                0.0        6291.0
# 2024-12-09                0.0                0.0        6291.0
# 2024-12-10                0.0                0.0        6291.0
#
#             trend_douleur%%std_31J  trend_méningite%%mean_31J
# 2019-01-01               25.015823                   2.225806
# 2019-01-02               25.246910                   2.225806
# 2019-01-03               25.268451                   2.225806
# 2019-01-04               25.400576                   2.225806
# 2019-01-05               25.472481                   2.225806
# ...                            ...                        ...
# 2024-12-06                0.000000                   0.000000
# 2024-12-07                0.000000                   0.000000
# 2024-12-08                0.000000                   0.000000
# 2024-12-09                0.000000                   0.000000
# 2024-12-10                0.000000                   0.000000
#
# [2171 rows x 1856 columns]

# %% [markdown]
# ### Increment by n days

# %%
n = 4
arsTabularDataset = update(arsTabularDataset, steps=n)
df = arsTabularDataset.data
df.shape
# Out:
# root 2024-12-10 12:17:12,177: INFO: Fetching dataset
# root 2024-12-10 12:17:12,185: INFO: Fetching data for hospitalfeatures at CHU Dijon is located at Dijon, 21231, Côte-d'Or, Bourgogne-Franche-Comté
# hospitalfeatures 2024-12-10 12:17:12,190: INFO: hospitalfeatures's data already fetched for CHU Dijon
# root 2024-12-10 12:17:12,204: INFO: Fetching data for airqualityfeatures at CHU Dijon is located at Dijon, 21231, Côte-d'Or, Bourgogne-Franche-Comté
# root 2024-12-10 12:17:12,207: INFO: airqualityfeatures's data already fetched for CHU Dijon
# root 2024-12-10 12:17:12,227: INFO: Fetching data for googletrendfeatures at CHU Dijon is located at Dijon, 21231, Côte-d'Or, Bourgogne-Franche-Comté
# root 2024-12-10 12:17:12,231: INFO: googletrendfeatures's data already fetched for CHU Dijon
# root 2024-12-10 12:17:12,247: INFO: Fetching data for meteorologicalfeatures at CHU Dijon is located at Dijon, 21231, Côte-d'Or, Bourgogne-Franche-Comté
# root 2024-12-10 12:17:12,249: INFO: meteorologicalfeatures's data already fetched for CHU Dijon
# root 2024-12-10 12:17:12,329: WARNING: Updating data
# root 2024-12-10 12:17:12,385: INFO: Fetching data for sociologicalfeatures at CHU Dijon is located at Dijon, 21231, Côte-d'Or, Bourgogne-Franche-Comté
# root 2024-12-10 12:17:12,387: INFO: sociologicalfeatures's data already fetched for CHU Dijon
# root 2024-12-10 12:17:12,400: INFO: Fetching data for populationfeatures at CHU Dijon is located at Dijon, 21231, Côte-d'Or, Bourgogne-Franche-Comté
# root 2024-12-10 12:17:12,402: INFO: populationfeatures's data already fetched for CHU Dijon
# root 2024-12-10 12:17:12,413: INFO: Fetching data for sportscompetitionfeatures at CHU Dijon is located at Dijon, 21231, Côte-d'Or, Bourgogne-Franche-Comté
# root 2024-12-10 12:17:12,415: INFO: sportscompetitionfeatures's data already fetched for CHU Dijon
# root 2024-12-10 12:17:12,424: INFO: Fetching data for trafficfeatures at CHU Dijon is located at Dijon, 21231, Côte-d'Or, Bourgogne-Franche-Comté
# root 2024-12-10 12:17:12,425: INFO: trafficfeatures's data already fetched for CHU Dijon
# root 2024-12-10 12:17:12,435: INFO: Fetching data for epidemiologicalfeatures at CHU Dijon is located at Dijon, 21231, Côte-d'Or, Bourgogne-Franche-Comté
# root 2024-12-10 12:17:12,437: INFO: epidemiologicalfeatures's data already fetched for CHU Dijon
# root 2024-12-10 12:17:12,447: INFO: Getting the dataset from 01-01-2019 to 15-12-2024 for CHU Dijon
# hospitalfeatures 2024-12-10 12:17:12,449: INFO: Getting data for hospitalfeatures from 2019-01-01 00:00:00 to 2024-12-15 00:00:00, at a 1D frequency
# hospitalfeatures 2024-12-10 12:17:12,460: INFO: Augmentation des features...
# root 2024-12-10 12:17:12,487: INFO: Getting data for airqualityfeatures from 2019-01-01 00:00:00 to 2024-12-15 00:00:00, at a 1D frequency
# root 2024-12-10 12:17:12,521: INFO: Augmentation des features...
# root 2024-12-10 12:17:12,740: INFO: Getting data for googletrendfeatures from 2019-01-01 00:00:00 to 2024-12-15 00:00:00, at a 1D frequency
# root 2024-12-10 12:17:12,825: INFO: Augmentation des features...
# root 2024-12-10 12:17:13,836: INFO: Getting data for meteorologicalfeatures from 2019-01-01 00:00:00 to 2024-12-15 00:00:00, at a 1D frequency
# root 2024-12-10 12:17:13,855: INFO: Augmentation des features...
# root 2024-12-10 12:17:13,979: WARNING: Plage des indices des lignes contenant des NaN: DatetimeIndex(['2019-01-01', '2019-01-02', '2019-01-03', '2019-01-04',
#                '2019-01-05', '2019-01-06', '2019-01-07', '2019-01-08',
#                '2019-01-09', '2019-01-10',
#                ...
#                '2024-12-01', '2024-12-02', '2024-12-03', '2024-12-04',
#                '2024-12-05', '2024-12-06', '2024-12-07', '2024-12-08',
#                '2024-12-09', '2024-12-10'],
#               dtype='datetime64[ns]', name='date', length=2171, freq=None)
# root 2024-12-10 12:17:13,981: WARNING: Colonnes contenant des NaN pour ces indices: ['meteo_station', 'meteo_station%%J-1', 'meteo_station%%J-2', 'meteo_station%%J-3', 'meteo_station%%J-4', 'meteo_station%%J-5', 'meteo_station%%J-6', 'meteo_station%%J-7']
# root 2024-12-10 12:17:13,983: INFO: Getting data for sociologicalfeatures from 2019-01-01 00:00:00 to 2024-12-15 00:00:00, at a 1D frequency
# root 2024-12-10 12:17:13,999: INFO: Augmentation des features...
# root 2024-12-10 12:17:14,110: WARNING: Plage des indices des lignes contenant des NaN: DatetimeIndex(['2023-12-31', '2024-01-01', '2024-01-02', '2024-01-03',
#                '2024-01-04', '2024-01-05', '2024-01-06', '2024-01-07'],
#               dtype='datetime64[ns]', name='date', freq=None)
# root 2024-12-10 12:17:14,117: WARNING: Colonnes contenant des NaN pour ces indices: ['borderHolidays', 'borderHolidays%%J-1', 'borderHolidays%%J-2', 'borderHolidays%%J-3', 'borderHolidays%%J-4', 'borderHolidays%%J-5', 'borderHolidays%%J-6', 'borderHolidays%%J-7']
# root 2024-12-10 12:17:14,118: INFO: Getting data for populationfeatures from 2019-01-01 00:00:00 to 2024-12-15 00:00:00, at a 1D frequency
# root 2024-12-10 12:17:14,162: INFO: Augmentation des features...
# root 2024-12-10 12:17:14,564: INFO: Getting data for sportscompetitionfeatures from 2019-01-01 00:00:00 to 2024-12-15 00:00:00, at a 1D frequency
# root 2024-12-10 12:17:14,571: INFO: Augmentation des features...
# root 2024-12-10 12:17:14,589: INFO: Getting data for trafficfeatures from 2019-01-01 00:00:00 to 2024-12-15 00:00:00, at a 1D frequency
# root 2024-12-10 12:17:14,597: INFO: Augmentation des features...
# root 2024-12-10 12:17:14,615: INFO: Getting data for epidemiologicalfeatures from 2019-01-01 00:00:00 to 2024-12-15 00:00:00, at a 1D frequency
# root 2024-12-10 12:17:14,631: INFO: Augmentation des features...
# root 2024-12-10 12:17:14,992: INFO: Creating the target columns as nb_emmergencies_CHU Dijon shifted by -1
# root 2024-12-10 12:17:14,996: INFO: Creating target history columns...
# root 2024-12-10 12:17:15,007: INFO: Rolling windows will start from 1 samples before to n days before this starting sample
# root 2024-12-10 12:17:15,079: INFO: Calculating train/val/test sets and encodings...
# Dropped 90 constant columns from both sets: {'PM10_FR26094', 'NO2_FR26094', 'trend_épilepsie', 'NO2_FR26010', 'PM10_FR26010', 'PM25_FR26094'}
# X shape: (1392, 1808), y shape: (1392, 1)
# [ColumnTransformer] .... (1 of 6) Processing pipeline-1, total=   0.1s
# [ColumnTransformer] .... (2 of 6) Processing pipeline-2, total=   0.0s
# [ColumnTransformer] .... (3 of 6) Processing pipeline-3, total=   0.0s
# [ColumnTransformer] .... (4 of 6) Processing pipeline-4, total=   0.1s
# root 2024-12-10 12:17:16,763: INFO: 47 features not encoded (same unit as target)
# [ColumnTransformer] .... (5 of 6) Processing pipeline-5, total=   0.1s
# [ColumnTransformer] ..... (6 of 6) Processing remainder, total=   0.0s
# (2175, 1856)

# %%
df
# Out:
#             O3_FR26005%%J-3  trend_fièvre%%J-5  trend_douleur%%mean_31J  \
# 2019-01-01             38.0                0.0                54.483871
# 2019-01-02             31.0                0.0                54.838710
# 2019-01-03             26.0                0.0                55.193548
# 2019-01-04             36.0                0.0                55.548387
# 2019-01-05             62.0                0.0                55.774194
# ...                     ...                ...                      ...
# 2024-12-10             58.0                0.0                79.000000
# 2024-12-11             58.0                0.0                79.000000
# 2024-12-12             58.0                0.0                79.000000
# 2024-12-13             58.0                0.0                79.000000
# 2024-12-14             58.0                0.0                79.000000
#
#             Y60T64%%mean_31J  meteo_pres%%J-7  meteo_snow%%J-3  \
# 2019-01-01      33434.354839           1034.5              0.0
# 2019-01-02      33434.354839           1034.5              0.0
# 2019-01-03      33434.354839           1034.5              0.0
# 2019-01-04      33434.354839           1034.5              0.0
# 2019-01-05      33434.354839           1034.5              0.0
# ...                      ...              ...              ...
# 2024-12-10      33749.000000           1021.7              0.0
# 2024-12-11      33749.000000              NaN              NaN
# 2024-12-12      33749.000000              NaN              NaN
# 2024-12-13      33749.000000              NaN              NaN
# 2024-12-14      33749.000000              NaN              NaN
#
#             trend_entorse%%mean_7J  meteo_snow%%std_365J  \
# 2019-01-01                     0.0              2.666901
# 2019-01-02                     0.0              2.666901
# 2019-01-03                     0.0              2.666901
# 2019-01-04                     0.0              2.666901
# 2019-01-05                     0.0              2.666901
# ...                            ...                   ...
# 2024-12-10                     0.0             22.617892
# 2024-12-11                     0.0                   NaN
# 2024-12-12                     0.0                   NaN
# 2024-12-13                     0.0                   NaN
# 2024-12-14                     0.0                   NaN
#
#             trend_médecin%%mean_31J  Y50T54%%std_7J  ...  \
# 2019-01-01                 3.225806        0.899735  ...
# 2019-01-02                 3.225806        0.899735  ...
# 2019-01-03                 3.225806        0.899735  ...
# 2019-01-04                 2.387097        0.899735  ...
# 2019-01-05                 2.387097        0.899735  ...
# ...                             ...             ...  ...
# 2024-12-10                16.000000        0.000000  ...
# 2024-12-11                16.000000        0.000000  ...
# 2024-12-12                16.000000        0.000000  ...
# 2024-12-13                16.000000        0.000000  ...
# 2024-12-14                16.000000        0.000000  ...
#
#             eveBankHolidays%%J-5  trend_allergie%%J-3  Y_LT5%%J-2  \
# 2019-01-01                 False                  0.0     26662.0
# 2019-01-02                 False                  0.0     26662.0
# 2019-01-03                 False                  0.0     26662.0
# 2019-01-04                 False                  0.0     26660.0
# 2019-01-05                 False                  0.0     26659.0
# ...                          ...                  ...         ...
# 2024-12-10                 False                  0.0     24333.0
# 2024-12-11                 False                  0.0     24333.0
# 2024-12-12                 False                  0.0     24333.0
# 2024-12-13                 False                  0.0     24333.0
# 2024-12-14                 False                  0.0     24333.0
#
#             trend_hypothermie%%J-7  trend_éruption cutanée%%J-6  \
# 2019-01-01                     0.0                          0.0
# 2019-01-02                     0.0                          0.0
# 2019-01-03                     0.0                          0.0
# 2019-01-04                     0.0                          0.0
# 2019-01-05                     0.0                         84.0
# ...                            ...                          ...
# 2024-12-10                     0.0                          0.0
# 2024-12-11                     0.0                          0.0
# 2024-12-12                     0.0                          0.0
# 2024-12-13                     0.0                          0.0
# 2024-12-14                     0.0                          0.0
#
#             trend_stress%%J-1  trend_noyade%%J-5  inc_ira%%J-7  \
# 2019-01-01                0.0                0.0           0.0
# 2019-01-02                0.0                0.0           0.0
# 2019-01-03                0.0                0.0           0.0
# 2019-01-04                0.0                0.0           0.0
# 2019-01-05                0.0                0.0           0.0
# ...                       ...                ...           ...
# 2024-12-10                0.0                0.0        6291.0
# 2024-12-11                0.0                0.0        6291.0
# 2024-12-12                0.0                0.0        6291.0
# 2024-12-13                0.0                0.0        6291.0
# 2024-12-14                0.0                0.0        6291.0
#
#             trend_douleur%%std_31J  trend_méningite%%mean_31J
# 2019-01-01               25.015823                   2.225806
# 2019-01-02               25.246910                   2.225806
# 2019-01-03               25.268451                   2.225806
# 2019-01-04               25.400576                   2.225806
# 2019-01-05               25.472481                   2.225806
# ...                            ...                        ...
# 2024-12-10                0.000000                   0.000000
# 2024-12-11                0.000000                   0.000000
# 2024-12-12                0.000000                   0.000000
# 2024-12-13                0.000000                   0.000000
# 2024-12-14                0.000000                   0.000000
#
# [2175 rows x 1856 columns]

# %% [markdown]
# ### State of the saved file

# %%
df_file = pd.read_feather(root_dir / 'data/features/meteorologicalfeatures/data_CHU Dijon.feather')
df_file
# Out:
#             meteo_tavg  meteo_tmin  meteo_tmax  meteo_prcp  meteo_snow  \
# date
# 2019-01-01         5.9         4.4         7.2         0.5         0.0
# 2019-01-02         4.6         2.6         6.6         0.0         0.0
# 2019-01-03         1.3        -2.2         4.4         0.0         0.0
# 2019-01-04         1.4        -1.4         5.1         0.0         0.0
# 2019-01-05         3.2        -1.0         5.0         0.0         0.0
# ...                ...         ...         ...         ...         ...
# 2024-12-06         7.6         4.0        11.0         5.3         0.0
# 2024-12-07         6.1         4.0         7.9         8.0         0.0
# 2024-12-08         5.3         4.8         5.9         5.4         0.0
# 2024-12-09         4.5         2.8         5.1         5.4         0.0
# 2024-12-10         2.9         1.6         3.8         0.0         0.0
#
#             meteo_wdir  meteo_wspd  meteo_pres meteo_station
# date
# 2019-01-01       319.0         6.2      1034.5          None
# 2019-01-02       343.0        17.4      1037.0          None
# 2019-01-03         5.0        14.1      1039.1          None
# 2019-01-04       359.0        11.0      1038.4          None
# 2019-01-05       323.0        11.0      1036.4          None
# ...                ...         ...         ...           ...
# 2024-12-06       227.0        13.8      1019.3          None
# 2024-12-07       207.0        17.7      1010.2          None
# 2024-12-08       278.0        12.7      1006.4          None
# 2024-12-09        13.0        23.8      1017.1          None
# 2024-12-10        19.0        18.0      1023.8          None
#
# [2171 rows x 9 columns]
