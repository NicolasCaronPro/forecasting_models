# %%
from bs4 import BeautifulSoup
from datetime import date

import numpy as np
import os
import pandas as pd
import requests

# %%
today = date.today()
d = today.strftime('%Y-%m-%d')
print("Today's date:", d)
# Out:
# Today's date: 2024-04-25

# %% [markdown]
# This url allow for the suffix ``#x`` at the very end of the url. `x` being the department number.
#
# You can use ```.format()``` to add it dynamically to the url
#
# I wasn't able to utilize this as it's not changing the page though.
# It's just worth mentioning.

# %%
bison_url = "http://tipi.bison-fute.gouv.fr/bison-fute-ouvert/publicationsDIR/Evenementiel-DIR/cnir/RecapBouchonsFranceEntiere.html"
bison_url
# Out:
# 'http://tipi.bison-fute.gouv.fr/bison-fute-ouvert/publicationsDIR/Evenementiel-DIR/cnir/RecapBouchonsFranceEntiere.html'

# %%
html = requests.get(bison_url)

# %%
bsobj = BeautifulSoup(html.content, 'html.parser')
bsobj
# Out:
# <html>
# <head>
# <meta content="text/html;charset=utf-8" http-equiv="Content-Type"/>
# <style type="text/css">body {
#     font-family:arial,tahoma,helvetica,sans-serif;
#     font-size:10pt;
#     font-size-adjust:none;
#     font-style:normal;
#     font-variant:normal;
#     font-weight:normal;
# }
#
# /*.version-regroupement {
# 	font-family: arial, tahoma, helvetica, sans-serif;
# 	font-size: 10pt;
# 	font-size-adjust: none;
# 	font-style: normal;
# 	font-variant: normal;
# 	font-weight: normal;
# }*/
#
# .nature {
# 	font-weight: bold;
# }
#
# .confidentialite-interne * {
# 	color: green !important;
# 	font-style: italic;
# }
#
# .confidentialite-autorites * {
# 	color: #CC0000 !important;
# }
#
# .confidentialite-gestionnaires-routiers * {
# 	color: blue !important;
# }
#
# .attribut-gestionnaire {
# 	color: blue;
# }
#
# .attribut-interne {
# 	color: green;
# }
#
# .attribut-important {
# 	font-weight: bold;
# }
#
# .separator-date+.separator-date:before {
# 	content: " - ";
# }
#
# .text-multiline {
# 	white-space: normal;
# }
# div.titreRecap {
#     text-align:center;
# }
# div.bloc {
#    margin: 10px 0 23px 30px;
# }
# .bold {
#    font-weight:bold;
# }
#
# .rupture{
#     font-style:italic;
#     margin-left : 25px;
# }
# div.interligne {
#     margin-bottom: 0.20cm;
# }
# </style>
# </head>
# <body>
# <div class="titreRecap">
# <span class="bold">Récapitulatif par départements</span>
# <br/> du 25 avril 2024 à 18h16
#     </div>Sélection :
#     <div class="bloc">Zone : France entière
#       <br/> Importance : *
#       <br/> Evénements : Bouchons
#       <br/>
# </div>
# <hr/>Index :
#     <br/>
# <a href="#06">06</a>
# <a href="#13">13</a>
# <a href="#25">25</a>
# <a href="#26">26</a>
# <a href="#28">28</a>
# <a href="#29">29</a>
# <a href="#31">31</a>
# <a href="#33">33</a>
# <a href="#34">34</a>
# <a href="#35">35</a>
# <a href="#38">38</a>
# <a href="#42">42</a>
# <a href="#44">44</a>
# <a href="#64">64</a>
# <a href="#66">66</a>
# <a href="#69">69</a>
# <a href="#73">73</a>
# <a href="#74">74</a>
# <a href="#76">76</a>
# <a href="#77">77</a>
# <a href="#78">78</a>
# <a href="#82">82</a>
# <a href="#83">83</a>
# <a href="#93">93</a>
# <hr/>
# <span class="rupture">
# <a name="06">Département 06 (Alpes-Maritimes)</a>
# </span>
# <br/>
# <br/>
# <div class="interligne"><span class="confidentialite-public" qname="marqueurs"><span qname="ligne_importance_vr"> <span qname="importance_vr_reduit">**</span></span></span><span class="confidentialite-public version-element" qname="element"><span qname="ligne_nature_ve"> <span class="nature" qname="nature_bouchon">Bouchon</span><span qname="lg_bouchon"> de 1,0 km</span><span qname="circulation">, circulation bloquée</span></span><span qname="ligne_axe_sens_pr">, <span qname="axe"> A8</span><span qname="sens_par_pole">, de Aix-en-Provence vers Italie - Genova</span><span qname="sens_cardinal"> (sens ouest-est</span><span qname="parenthese">)</span></span><span qname="ligne_axe_pr">, <span qname="pr">entre les PR 164+199 et 165+199</span><span qname="longueur"> (sur 1,0 km)</span></span><span qname="ligne_commune">, <span qname="commune">à Mougins</span></span><span qname="ligne_commentaire_public">, <span class="text-multiline" qname="commentaire_public">Trafic bouche.</span></span></span><span class="origine" qname="origine"> ; <span qname="ligne_origine_vr"> <span qname="origine_ve_crochet_debut"> [</span><span qname="origine_vr">Origine : SCA Escota (fr204)</span><span qname="origine_ve_crochet_fin">]</span></span></span></div>
# <div class="interligne"><span class="confidentialite-public" qname="marqueurs"><span qname="ligne_importance_vr"> <span qname="importance_vr_reduit">**</span></span></span><span class="confidentialite-public version-element" qname="element"><span qname="ligne_nature_ve"> <span class="nature" qname="nature_bouchon">Bouchon</span><span qname="lg_bouchon"> de 1,0 km</span></span><span qname="ligne_axe_sens_pr">, <span qname="axe"> A8</span><span qname="sens_par_pole">, de Italie - Genova vers Aix-en-Provence</span><span qname="sens_cardinal"> (sens est-ouest</span><span qname="parenthese">)</span></span><span qname="ligne_axe_pr">, <span qname="pr">entre les PR 186+536 et 185+536</span><span qname="longueur"> (sur 1,0 km)</span></span><span qname="ligne_commune">, <span qname="commune">à Nice</span></span><span qname="ligne_commentaire_public">, <span class="text-multiline" qname="commentaire_public">Trafic ralenti.</span></span></span><span class="origine" qname="origine"> ; <span qname="ligne_origine_vr"> <span qname="origine_ve_crochet_debut"> [</span><span qname="origine_vr">Origine : SCA Escota (fr204)</span><span qname="origine_ve_crochet_fin">]</span></span></span></div>
# <div class="interligne"><span class="confidentialite-public" qname="marqueurs"><span qname="ligne_importance_vr"> <span qname="importance_vr_reduit">**</span></span></span><span class="confidentialite-public version-element" qname="element"><span qname="ligne_nature_ve"> <span class="nature" qname="nature_bouchon">Bouchon</span><span qname="lg_bouchon"> de 1,5 km</span></span><span qname="ligne_axe_sens_pr">, <span qname="axe"> A8</span><span qname="sens_par_pole">, de Italie - Genova vers Aix-en-Provence</span><span qname="sens_cardinal"> (sens est-ouest</span><span qname="parenthese">)</span></span><span qname="ligne_axe_pr">, <span qname="pr">entre les PR 190+629 et 189+129</span><span qname="longueur"> (sur 1,5 km)</span></span><span qname="ligne_commune">, <span qname="commune">à Nice</span></span><span qname="ligne_commentaire_public">, <span class="text-multiline" qname="commentaire_public">Trafic ralenti.</span></span></span><span class="origine" qname="origine"> ; <span qname="ligne_origine_vr"> <span qname="origine_ve_crochet_debut"> [</span><span qname="origine_vr">Origine : SCA Escota (fr204)</span><span qname="origine_ve_crochet_fin">]</span></span></span></div>
# <div class="interligne"><span class="confidentialite-public" qname="marqueurs"><span qname="ligne_importance_vr"> <span qname="importance_vr_reduit">**</span></span></span><span class="confidentialite-public version-element" qname="element"><span qname="ligne_nature_ve"> <span class="nature" qname="nature_bouchon">Bouchon</span><span qname="lg_bouchon"> de 6,0 km</span><span qname="circulation">, circulation bloquée</span></span><span qname="ligne_axe_sens_pr">, <span qname="axe"> A8</span><span qname="sens_par_pole">, de Italie - Genova vers Aix-en-Provence</span><span qname="sens_cardinal"> (sens est-ouest</span><span qname="parenthese">)</span></span><span qname="ligne_axe_pr">, <span qname="pr">entre les PR 199+514 et 193+514</span><span qname="longueur"> (sur 6,0 km)</span></span><span qname="ligne_commune">, <span qname="commune">à Nice</span></span><span qname="ligne_commentaire_public">, <span class="text-multiline" qname="commentaire_public">Trafic bouche.</span></span></span><span class="origine" qname="origine"> ; <span qname="ligne_origine_vr"> <span qname="origine_ve_crochet_debut"> [</span><span qname="origine_vr">Origine : SCA Escota (fr204)</span><span qname="origine_ve_crochet_fin">]</span></span></span></div>
# <div class="interligne"><span class="confidentialite-public" qname="marqueurs"><span qname="ligne_importance_vr"> <span qname="importance_vr_reduit">**</span></span></span><span class="confidentialite-public version-element" qname="element"><span qname="ligne_nature_ve"> <span class="nature" qname="nature_bouchon">Bouchon</span><span qname="lg_bouchon"> de 2,5 km</span><span qname="circulation">, circulation bloquée</span></span><span qname="ligne_axe_sens_pr">, <span qname="axe"> A8</span><span qname="sens_par_pole">, de Italie - Genova vers Aix-en-Provence</span><span qname="sens_cardinal"> (sens est-ouest</span><span qname="parenthese">)</span></span><span qname="ligne_axe_pr">, <span qname="pr">entre les PR 209+903 et 207+403</span><span qname="longueur"> (sur 2,5 km)</span></span><span qname="ligne_commune">, <span qname="commune">de La Turbie à La Trinité</span></span><span qname="ligne_commentaire_public">, <span class="text-multiline" qname="commentaire_public">Trafic bouche.</span></span></span><span class="origine" qname="origine"> ; <span qname="ligne_origine_vr"> <span qname="origine_ve_crochet_debut"> [</span><span qname="origine_vr">Origine : SCA Escota (fr204)</span><span qname="origine_ve_crochet_fin">]</span></span></span></div>
# <div class="interligne"><span class="confidentialite-public" qname="marqueurs"><span qname="ligne_importance_vr"> <span qname="importance_vr_reduit">*</span></span></span><span class="confidentialite-public version-element" qname="element"><span qname="ligne_nature_ve"> <span class="nature" qname="nature_bouchon">Bouchon</span></span><span qname="ligne_axe_sens_pr">, <span qname="axe">A8</span><span qname="sens_par_pole">, de Italie - Genova vers Aix-en-Provence</span><span qname="sens_cardinal"> (sens est-ouest</span><span qname="parenthese">)</span></span><span qname="ligne_axe_pr">, <span qname="pr">au PR 164+855</span></span><span qname="ligne_commune">, <span qname="commune">à Mougins</span></span><span qname="ligne_commentaire_public">, <span class="text-multiline" qname="commentaire_public">Trafic dense.</span></span></span><span class="origine" qname="origine"> ; <span qname="ligne_origine_vr"> <span qname="origine_ve_crochet_debut"> [</span><span qname="origine_vr">Origine : SCA Escota (fr204)</span><span qname="origine_ve_crochet_fin">]</span></span></span></div>
# <div class="interligne"><span class="confidentialite-public" qname="marqueurs"><span qname="ligne_importance_vr"> <span qname="importance_vr_reduit">*</span></span></span><span class="confidentialite-public version-element" qname="element"><span qname="ligne_nature_ve"> <span class="nature" qname="nature_bouchon">Bouchon</span></span><span qname="ligne_axe_sens_pr">, <span qname="axe">A8</span><span qname="sens_par_pole">, de Aix-en-Provence vers Italie - Genova</span><span qname="sens_cardinal"> (sens ouest-est</span><span qname="parenthese">)</span></span><span qname="ligne_axe_pr">, <span qname="pr">au PR 164+855</span></span><span qname="ligne_commune">, <span qname="commune">à Mougins</span></span><span qname="ligne_commentaire_public">, <span class="text-multiline" qname="commentaire_public">Trafic dense.</span></span></span><span class="origine" qname="origine"> ; <span qname="ligne_origine_vr"> <span qname="origine_ve_crochet_debut"> [</span><span qname="origine_vr">Origine : SCA Escota (fr204)</span><span qname="origine_ve_crochet_fin">]</span></span></span></div>
# <br/>
# <hr/>
# <span class="rupture">
# <a name="13">Département 13 (Bouches-du-Rhône)</a>
# </span>
# <br/>
# <br/>
# <div class="interligne"><span class="confidentialite-public" qname="marqueurs"><span qname="ligne_importance_vr"> <span qname="importance_vr_reduit">**</span></span></span><span class="confidentialite-public version-element" qname="element"><span qname="ligne_nature_ve"> <span class="nature" qname="nature_bouchon">Ralentissement</span><span qname="lg_bouchon"> de 0,5 km</span><span qname="nbr_voies"> toutes les voies</span></span><span qname="ligne_axe_sens_pr">, <span qname="axe"> A54</span><span qname="sens_par_pole">, de Nîmes (A9) vers Salon-de-Provence (A7)</span><span qname="sens_cardinal"> (sens ouest-est</span><span qname="parenthese">)</span></span><span qname="ligne_impact">, <span qname="nature_impact_libelle">Impact : </span><span qname="nature_impact">voies rétrécies</span></span><span qname="ligne_axe_pr">, <span qname="pr">entre les PR 71+500 et 72</span><span qname="longueur"> (sur 0,5 km)</span></span><span qname="ligne_commune">, <span qname="commune">à Salon-de-Provence</span></span><span qname="ligne_complementaire">, <span qname="toutes_voies">Sur toutes les voies</span></span></span><span class="origine" qname="origine"> ; <span qname="ligne_origine_vr"> <span qname="origine_ve_crochet_debut"> [</span><span qname="origine_vr">Origine : SCA ASF</span><span qname="origine_ve_crochet_fin">]</span></span></span></div>
# <div class="interligne"><span class="confidentialite-public" qname="marqueurs"><span qname="ligne_importance_vr"> <span qname="importance_vr_reduit">**</span></span></span><span class="confidentialite-public version-element" qname="element"><span qname="ligne_nature_ve"> <span class="nature" qname="nature_bouchon">Ralentissement</span><span qname="lg_bouchon"> de 1,5 km</span><span qname="nbr_voies"> toutes les voies</span></span><span qname="ligne_axe_sens_pr">, <span qname="axe"> A7</span><span qname="sens_par_pole">, de Marseille vers Lyon</span><span qname="sens_cardinal"> (sens sud-nord</span><span qname="parenthese">)</span></span><span qname="ligne_impact">, <span qname="nature_impact_libelle">Impact : </span><span qname="nature_impact">voies rétrécies</span></span><span qname="ligne_axe_pr">, <span qname="pr">entre les PR 237+500 et 236</span><span qname="longueur"> (sur 1,5 km)</span></span><span qname="ligne_commune">, <span qname="commune">à Lançon-Provence</span></span><span qname="ligne_complementaire">, <span qname="toutes_voies">Sur toutes les voies</span></span></span><span class="origine" qname="origine"> ; <span qname="ligne_origine_vr"> <span qname="origine_ve_crochet_debut"> [</span><span qname="origine_vr">Origine : SCA ASF</span><span qname="origine_ve_crochet_fin">]</span></span></span></div>
# <br/>
# <hr/>
# <span class="rupture">
# <a name="25">Département 25 (Doubs)</a>
# </span>
# <br/>
# <br/>
# <div class="interligne"><span class="confidentialite-public" qname="marqueurs"><span qname="ligne_importance_vr"> <span qname="importance_vr_reduit">**</span></span></span><span class="confidentialite-public version-element" qname="element"><span qname="ligne_nature_ve"> <span class="nature" qname="nature_bouchon">Bouchon</span><span qname="lg_bouchon"> de 3,8 km</span></span><span qname="ligne_horodate_fin_exception_ve">, <span class="separator-date" qname="horodate_fin_reduit_ve_evt_encours">prévu jusqu'à 19h</span></span><span qname="ligne_axe_sens_pr">, <span qname="axe"> N57</span><span qname="sens_par_pole">, de Metz vers Suisse - Lausanne</span><span qname="sens_cardinal"> (sens nord-sud</span><span qname="parenthese">)</span></span><span qname="ligne_axe_pr">, <span qname="pr">entre les PR 12 et 15</span><span qname="longueur"> (sur 3,9 km)</span></span><span qname="ligne_commune">, <span qname="commune">de Besançon à Beure</span></span><span qname="ligne_tendane">, <span qname="normalite">aussi chargé que d'habitude</span></span></span><span class="origine" qname="origine"> ; <span qname="ligne_origine_vr"> <span qname="origine_ve_crochet_debut"> [</span><span qname="origine_vr">Origine : DIRE Besançon Vauban</span><span qname="origine_ve_crochet_fin">]</span></span></span></div>
# <br/>
# <hr/>
# <span class="rupture">
# <a name="26">Département 26 (Drôme)</a>
# </span>
# <br/>
# <br/>
# <div class="interligne"><span class="confidentialite-public" qname="marqueurs"><span qname="ligne_importance_vr"> <span qname="importance_vr_reduit">**</span></span></span><span class="confidentialite-public version-element" qname="element"><span qname="ligne_nature_ve"> <span class="nature" qname="nature_bouchon">Ralentissement</span><span qname="lg_bouchon"> de 2,5 km</span><span qname="nbr_voies"> toutes les voies</span></span><span qname="ligne_axe_sens_pr">, <span qname="axe"> A7</span><span qname="sens_par_pole">, de Marseille vers Lyon</span><span qname="sens_cardinal"> (sens sud-nord</span><span qname="parenthese">)</span></span><span qname="ligne_impact">, <span qname="nature_impact_libelle">Impact : </span><span qname="nature_impact">voies rétrécies</span></span><span qname="ligne_axe_pr">, <span qname="pr">entre les PR 85 et 82+500</span><span qname="longueur"> (sur 2,5 km)</span></span><span qname="ligne_commune">, <span qname="commune">de Livron-sur-Drôme à Étoile-sur-Rhône</span></span><span qname="ligne_complementaire">, <span qname="toutes_voies">Sur toutes les voies</span></span></span><span class="origine" qname="origine"> ; <span qname="ligne_origine_vr"> <span qname="origine_ve_crochet_debut"> [</span><span qname="origine_vr">Origine : SCA ASF</span><span qname="origine_ve_crochet_fin">]</span></span></span></div>
# <br/>
# <hr/>
# <span class="rupture">
# <a name="28">Département 28 (Eure-et-Loir)</a>
# </span>
# <br/>
# <br/>
# <div class="interligne"><span class="confidentialite-public" qname="marqueurs"><span qname="ligne_importance_vr"> <span qname="importance_vr_reduit">**</span></span></span><span class="confidentialite-public version-element" qname="element"><span qname="ligne_nature_ve"> <span class="nature" qname="nature_bouchon">Bouchon</span><span qname="lg_bouchon"> de 2,5 km</span><span qname="nbr_voies"> toutes les voies</span></span><span qname="ligne_axe_sens_pr">, <span qname="axe"> A11</span><span qname="sens_par_pole">, de Nantes vers Paris</span><span qname="sens_cardinal"> (sens ouest-est</span><span qname="parenthese">)</span></span><span qname="ligne_impact">, <span qname="nature_impact_libelle">Impact : </span><span qname="nature_impact">voies neutralisées</span></span><span qname="ligne_axe_pr">, <span qname="pr">entre les PR 41 et 38+500</span><span qname="longueur"> (sur 2,6 km)</span></span><span qname="ligne_commune">, <span qname="commune">de Ymeray à Bleury</span></span><span qname="ligne_complementaire">, <span qname="toutes_voies">Sur toutes les voies</span></span></span><span class="origine" qname="origine"> ; <span qname="ligne_origine_vr"> <span qname="origine_ve_crochet_debut"> [</span><span qname="origine_vr">Origine : SCA Cofiroute</span><span qname="origine_ve_crochet_fin">]</span></span></span></div>
# <br/>
# <hr/>
# <span class="rupture">
# <a name="29">Département 29 (Finistère)</a>
# </span>
# <br/>
# <br/>
# <div class="interligne"><span class="confidentialite-public" qname="marqueurs"><span qname="ligne_importance_vr"> <span qname="importance_vr_reduit">**</span></span></span><span class="confidentialite-public version-element" qname="element"><span qname="ligne_nature_ve"> <span class="nature" qname="nature_bouchon">Bouchon</span><span qname="lg_bouchon"> de 1,4 km</span><span qname="nbr_voies"> toutes les voies</span></span><span qname="ligne_axe_sens_pr">, <span qname="axe"> N265</span><span qname="sens_par_pole">, de Brest vers Nantes</span><span qname="sens_cardinal"> (sens nord-sud</span><span qname="parenthese">)</span></span><span qname="ligne_axe_pr">, <span qname="pr">entre les PR 2+300 et 0+50</span><span qname="longueur"> (sur 1,4 km)</span></span><span qname="ligne_commune">, <span qname="commune">de Guipavas à Le Relecq-Kerhuon</span></span><span qname="ligne_complementaire">, <span qname="toutes_voies">Sur toutes les voies</span></span></span><span class="origine" qname="origine"> ; <span qname="ligne_origine_vr"> <span qname="origine_ve_crochet_debut"> [</span><span qname="origine_vr">Origine : DIRO Rennes</span><span qname="origine_ve_crochet_fin">]</span></span></span></div>
# <br/>
# <hr/>
# <span class="rupture">
# <a name="31">Département 31 (Haute-Garonne)</a>
# </span>
# <br/>
# <br/>
# <div class="interligne"><span class="confidentialite-public" qname="marqueurs"><span qname="ligne_importance_vr"> <span qname="importance_vr_reduit">**</span></span></span><span class="confidentialite-public version-element" qname="element"><span qname="ligne_nature_ve"> <span class="nature" qname="nature_bouchon">Ralentissement</span><span qname="lg_bouchon"> de 2,0 km</span><span qname="nbr_voies"> toutes les voies</span></span><span qname="ligne_axe_sens_pr">, <span qname="axe"> A61</span><span qname="sens_par_pole">, de Toulouse vers Narbonne</span><span qname="sens_cardinal"> (sens intérieur</span><span qname="parenthese">)</span></span><span qname="ligne_impact">, <span qname="nature_impact_libelle">Impact : </span><span qname="nature_impact">voies rétrécies</span></span><span qname="ligne_axe_pr">, <span qname="pr">entre les PR 236+500 et 238+500</span><span qname="longueur"> (sur 2,0 km)</span></span><span qname="ligne_commune">, <span qname="commune">à Toulouse</span></span><span qname="ligne_complementaire">, <span qname="toutes_voies">Sur toutes les voies</span></span></span><span class="origine" qname="origine"> ; <span qname="ligne_origine_vr"> <span qname="origine_ve_crochet_debut"> [</span><span qname="origine_vr">Origine : SCA ASF</span><span qname="origine_ve_crochet_fin">]</span></span></span></div>
# <div class="interligne"><span class="confidentialite-public" qname="marqueurs"><span qname="ligne_importance_vr"> <span qname="importance_vr_reduit">**</span></span></span><span class="confidentialite-public version-element" qname="element"><span qname="ligne_nature_ve"> <span class="nature" qname="nature_bouchon">Bouchon</span><span qname="lg_bouchon"> de 2,0 km</span><span qname="nbr_voies"> toutes les voies</span></span><span qname="ligne_axe_sens_pr">, <span qname="axe"> A61</span><span qname="sens_par_pole">, de Narbonne vers Toulouse</span><span qname="sens_cardinal"> (sens extérieur</span><span qname="parenthese">)</span></span><span qname="ligne_impact">, <span qname="nature_impact_libelle">Impact : </span><span qname="nature_impact">voies rétrécies</span></span><span qname="ligne_axe_pr">, <span qname="pr">entre les PR 240+500 et 238+500</span><span qname="longueur"> (sur 2,0 km)</span></span><span qname="ligne_commune">, <span qname="commune">de Labège à Toulouse</span></span><span qname="ligne_complementaire">, <span qname="toutes_voies">Sur toutes les voies</span></span></span><span class="origine" qname="origine"> ; <span qname="ligne_origine_vr"> <span qname="origine_ve_crochet_debut"> [</span><span qname="origine_vr">Origine : SCA ASF</span><span qname="origine_ve_crochet_fin">]</span></span></span></div>
# <div class="interligne"><span class="confidentialite-public" qname="marqueurs"><span qname="ligne_importance_vr"> <span qname="importance_vr_reduit">**</span></span></span><span class="confidentialite-public version-element" qname="element"><span qname="ligne_nature_ve"> <span class="nature" qname="nature_bouchon">Bouchon</span><span qname="lg_bouchon"> de 2,4 km</span><span qname="nbr_voies"> toutes les voies</span></span><span qname="ligne_axe_sens_pr">, <span qname="axe"> A620</span><span qname="sens_par_pole">, de Toulouse sud vers Toulouse nord</span><span qname="sens_cardinal"> (sens intérieur</span><span qname="parenthese">)</span></span><span qname="ligne_axe_pr">, <span qname="pr">entre les PR 5+123 et 2+664</span><span qname="longueur"> (sur 2,5 km)</span></span><span qname="ligne_commune">, <span qname="commune">à Toulouse</span></span><span qname="ligne_complementaire">, <span qname="toutes_voies">Sur toutes les voies</span></span></span><span class="origine" qname="origine"> ; <span qname="ligne_origine_vr"> <span qname="origine_ve_crochet_debut"> [</span><span qname="origine_vr">Origine : DIRSO Toulouse Sagacité</span><span qname="origine_ve_crochet_fin">]</span></span></span></div>
# <div class="interligne"><span class="confidentialite-public" qname="marqueurs"><span qname="ligne_importance_vr"> <span qname="importance_vr_reduit">**</span></span></span><span class="confidentialite-public version-element" qname="element"><span qname="ligne_nature_ve"> <span class="nature" qname="nature_bouchon">Bouchon</span><span qname="lg_bouchon"> de 4,9 km</span><span qname="nbr_voies"> toutes les voies</span></span><span qname="ligne_axe_sens_pr">, <span qname="axe"> A620</span><span qname="sens_par_pole">, de Toulouse nord vers Toulouse sud</span><span qname="sens_cardinal"> (sens extérieur</span><span qname="parenthese">)</span></span><span qname="ligne_axe_pr">, <span qname="pr">entre les PR 6+767 et 11+666</span><span qname="longueur"> (sur 5,0 km)</span></span><span qname="ligne_commune">, <span qname="commune">à Toulouse</span></span><span qname="ligne_complementaire">, <span qname="toutes_voies">Sur toutes les voies</span></span></span><span class="origine" qname="origine"> ; <span qname="ligne_origine_vr"> <span qname="origine_ve_crochet_debut"> [</span><span qname="origine_vr">Origine : DIRSO Toulouse Sagacité</span><span qname="origine_ve_crochet_fin">]</span></span></span></div>
# <div class="interligne"><span class="confidentialite-public" qname="marqueurs"><span qname="ligne_importance_vr"> <span qname="importance_vr_reduit">**</span></span></span><span class="confidentialite-public version-element" qname="element"><span qname="ligne_nature_ve"> <span class="nature" qname="nature_bouchon">Bouchon</span><span qname="lg_bouchon"> de 1,0 km</span><span qname="nbr_voies"> toutes les voies</span></span><span qname="ligne_axe_sens_pr">, <span qname="axe"> A621</span><span qname="sens_par_pole">, de Aéroport Blagnac vers Toulouse</span><span qname="sens_cardinal"> (sens ouest-est</span><span qname="parenthese">)</span></span><span qname="ligne_axe_pr">, <span qname="pr">entre les PR 2+929 et 1+929</span><span qname="longueur"> (sur 1,0 km)</span></span><span qname="ligne_commune">, <span qname="commune">à Blagnac</span></span><span qname="ligne_complementaire">, <span qname="toutes_voies">Sur toutes les voies</span></span></span><span class="origine" qname="origine"> ; <span qname="ligne_origine_vr"> <span qname="origine_ve_crochet_debut"> [</span><span qname="origine_vr">Origine : DIRSO Toulouse Sagacité</span><span qname="origine_ve_crochet_fin">]</span></span></span></div>
# <div class="interligne"><span class="confidentialite-public" qname="marqueurs"><span qname="ligne_importance_vr"> <span qname="importance_vr_reduit">**</span></span></span><span class="confidentialite-public version-element" qname="element"><span qname="ligne_nature_ve"> <span class="nature" qname="nature_bouchon">Bouchon</span><span qname="lg_bouchon"> de 3,5 km</span><span qname="nbr_voies"> toutes les voies</span></span><span qname="ligne_axe_sens_pr">, <span qname="axe"> A624</span><span qname="sens_par_pole">, de Colomiers (N124) vers Toulouse</span><span qname="sens_cardinal"> (sens ouest-est</span><span qname="parenthese">)</span></span><span qname="ligne_axe_pr">, <span qname="pr">entre les PR 3+762 et 0+695</span><span qname="longueur"> (sur 3,5 km)</span></span><span qname="ligne_commune">, <span qname="commune">à Toulouse</span></span><span qname="ligne_complementaire">, <span qname="toutes_voies">Sur toutes les voies</span></span></span><span class="origine" qname="origine"> ; <span qname="ligne_origine_vr"> <span qname="origine_ve_crochet_debut"> [</span><span qname="origine_vr">Origine : DIRSO Toulouse Sagacité</span><span qname="origine_ve_crochet_fin">]</span></span></span></div>
# <div class="interligne"><span class="confidentialite-public" qname="marqueurs"><span qname="ligne_importance_vr"> <span qname="importance_vr_reduit">**</span></span></span><span class="confidentialite-public version-element" qname="element"><span qname="ligne_nature_ve"> <span class="nature" qname="nature_bouchon">Bouchon</span><span qname="lg_bouchon"> de 2,8 km</span><span qname="nbr_voies"> toutes les voies</span></span><span qname="ligne_axe_sens_pr">, <span qname="axe"> A624</span><span qname="sens_par_pole">, de Toulouse vers Colomiers (N124)</span><span qname="sens_cardinal"> (sens est-ouest</span><span qname="parenthese">)</span></span><span qname="ligne_axe_pr">, <span qname="pr">entre les PR 0+535 et 3+136</span><span qname="longueur"> (sur 2,8 km)</span></span><span qname="ligne_commune">, <span qname="commune">à Toulouse</span></span><span qname="ligne_complementaire">, <span qname="toutes_voies">Sur toutes les voies</span></span></span><span class="origine" qname="origine"> ; <span qname="ligne_origine_vr"> <span qname="origine_ve_crochet_debut"> [</span><span qname="origine_vr">Origine : DIRSO Toulouse Sagacité</span><span qname="origine_ve_crochet_fin">]</span></span></span></div>
# <div class="interligne"><span class="confidentialite-public" qname="marqueurs"><span qname="ligne_importance_vr"> <span qname="importance_vr_reduit">**</span></span></span><span class="confidentialite-public version-element" qname="element"><span qname="ligne_nature_ve"> <span class="nature" qname="nature_bouchon">Ralentissement</span><span qname="lg_bouchon"> de 2,0 km</span><span qname="nbr_voies"> toutes les voies</span></span><span qname="ligne_axe_sens_pr">, <span qname="axe"> A64</span><span qname="sens_par_pole">, de Toulouse vers Bayonne</span><span qname="sens_cardinal"> (sens nord-sud</span><span qname="parenthese">)</span></span><span qname="ligne_impact">, <span qname="nature_impact_libelle">Impact : </span><span qname="nature_impact">voies rétrécies</span></span><span qname="ligne_axe_pr">, <span qname="pr">entre les PR 287 et 285</span><span qname="longueur"> (sur 2,0 km)</span></span><span qname="ligne_commune">, <span qname="commune">à Toulouse</span></span><span qname="ligne_complementaire">, <span qname="toutes_voies">Sur toutes les voies</span></span></span><span class="origine" qname="origine"> ; <span qname="ligne_origine_vr"> <span qname="origine_ve_crochet_debut"> [</span><span qname="origine_vr">Origine : SCA ASF</span><span qname="origine_ve_crochet_fin">]</span></span></span></div>
# <div class="interligne"><span class="confidentialite-public" qname="marqueurs"><span qname="ligne_importance_vr"> <span qname="importance_vr_reduit">**</span></span></span><span class="confidentialite-public version-element" qname="element"><span qname="ligne_horodates_element_ve"> <span class="separator-date" qname="horodates_constatation_reduit_ve">À 16h29</span></span><span qname="ligne_nature_ve">, <span class="nature" qname="nature_bouchon">Bouchon</span><span qname="lg_bouchon"> de 2,6 km</span><span qname="nbr_voies"> sur 0 voie</span></span><span qname="ligne_axe_sens_pr">, <span qname="axe"> A621</span><span qname="sens_par_pole">, de Toulouse vers Aéroport Blagnac</span><span qname="sens_cardinal"> (sens est-ouest</span><span qname="parenthese">)</span></span><span qname="ligne_axe_pr">, <span qname="pr">entre les PR 1+188 et 3+784</span><span qname="longueur"> (sur 2,6 km)</span></span><span qname="ligne_commune">, <span qname="commune">de Toulouse à Blagnac</span></span></span><span class="origine" qname="origine"> ; <span qname="ligne_origine_vr"> <span qname="origine_ve_crochet_debut"> [</span><span qname="origine_vr">Origine : DIRSO Toulouse Sagacité</span><span qname="origine_ve_crochet_fin">]</span></span></span></div>
# <br/>
# <hr/>
# <span class="rupture">
# <a name="33">Département 33 (Gironde)</a>
# </span>
# <br/>
# <br/>
# <div class="interligne"><span class="confidentialite-public" qname="marqueurs"><span qname="ligne_importance_vr"> <span qname="importance_vr_reduit">**</span></span></span><span class="confidentialite-public version-element" qname="element"><span qname="ligne_nature_ve"> <span class="nature" qname="nature_bouchon">Ralentissement</span><span qname="lg_bouchon"> de 2,0 km</span><span qname="nbr_voies"> toutes les voies</span></span><span qname="ligne_axe_sens_pr">, <span qname="axe"> A10</span><span qname="sens_par_pole">, de Bordeaux vers Paris</span><span qname="sens_cardinal"> (sens sud-nord</span><span qname="parenthese">)</span></span><span qname="ligne_impact">, <span qname="nature_impact_libelle">Impact : </span><span qname="nature_impact">voies rétrécies</span></span><span qname="ligne_axe_pr">, <span qname="pr">entre les PR 542+954 et 541</span><span qname="longueur"> (sur 2,0 km)</span></span><span qname="ligne_commune">, <span qname="commune">de Lormont à Carbon-Blanc</span></span><span qname="ligne_complementaire">, <span qname="toutes_voies">Sur toutes les voies</span></span></span><span class="origine" qname="origine"> ; <span qname="ligne_origine_vr"> <span qname="origine_ve_crochet_debut"> [</span><span qname="origine_vr">Origine : SCA ASF</span><span qname="origine_ve_crochet_fin">]</span></span></span></div>
# <br/>
# <hr/>
# <span class="rupture">
# <a name="34">Département 34 (Hérault)</a>
# </span>
# <br/>
# <br/>
# <div class="interligne"><span class="confidentialite-public" qname="marqueurs"><span qname="ligne_importance_vr"> <span qname="importance_vr_reduit">**</span></span></span><span class="confidentialite-public version-element" qname="element"><span qname="ligne_nature_ve"> <span class="nature" qname="nature_bouchon">Ralentissement</span><span qname="lg_bouchon"> de 2,5 km</span><span qname="nbr_voies"> toutes les voies</span></span><span qname="ligne_axe_sens_pr">, <span qname="axe"> A709</span><span qname="sens_cardinal"> (sens nord-sud</span><span qname="parenthese">)</span></span><span qname="ligne_impact">, <span qname="nature_impact_libelle">Impact : </span><span qname="nature_impact">voies rétrécies</span></span><span qname="ligne_axe_pr">, <span qname="pr">entre les PR 17 et 19+500</span><span qname="longueur"> (sur 2,6 km)</span></span><span qname="ligne_commune">, <span qname="commune">de Lattes à Saint-Jean-de-Védas</span></span><span qname="ligne_complementaire">, <span qname="toutes_voies">Sur toutes les voies</span></span></span><span class="origine" qname="origine"> ; <span qname="ligne_origine_vr"> <span qname="origine_ve_crochet_debut"> [</span><span qname="origine_vr">Origine : SCA ASF</span><span qname="origine_ve_crochet_fin">]</span></span></span></div>
# <div class="interligne"><span class="confidentialite-public" qname="marqueurs"><span qname="ligne_importance_vr"> <span qname="importance_vr_reduit">*</span></span></span><span class="confidentialite-public version-element" qname="element"><span qname="ligne_nature_ve"> <span class="nature" qname="nature_bouchon">Ralentissement</span><span qname="lg_bouchon"> de 0,4 km</span><span qname="nbr_voies"> toutes les voies</span></span><span qname="ligne_axe_sens_pr">, <span qname="axe"> A709</span><span qname="sens_cardinal"> (sens sud-nord</span><span qname="parenthese">)</span></span><span qname="ligne_impact">, <span qname="nature_impact_libelle">Impact : </span><span qname="nature_impact">voies rétrécies</span><span qname="nature_impact_libelle">Impact : </span><span qname="nature_impact">voies rétrécies</span></span><span qname="ligne_axe_pr">, <span qname="pr">entre les PR 11+500 et 11+70</span><span qname="longueur"> (sur 0,5 km)</span></span><span qname="ligne_commune">, <span qname="commune">à Montpellier</span></span><span qname="ligne_complementaire">, <span qname="toutes_voies">Sur toutes les voies</span></span></span><span class="confidentialite-public version-element" qname="element"> ; <span qname="ligne_nature_ve"> <span class="nature" qname="nature_bouchon">Ralentissement</span><span qname="lg_bouchon"> de 0,3 km</span><span qname="nbr_voies"> toutes les voies</span></span><span qname="ligne_axe_pr">, <span qname="pr">entre les PR 11+70 et 10+800</span><span qname="longueur"> (sur 0,3 km)</span></span><span qname="ligne_complementaire">, <span qname="objetMetier">se termine à proximité  d'un Échangeur</span></span><span qname="ligne_complementaire">, <span qname="toutes_voies">Sur toutes les voies</span></span></span><span class="origine" qname="origine"> ; <span qname="ligne_origine_vr"> <span qname="origine_ve_crochet_debut"> [</span><span qname="origine_vr">Origine : SCA ASF</span><span qname="origine_ve_crochet_fin">]</span></span></span></div>
# <br/>
# <hr/>
# <span class="rupture">
# <a name="35">Département 35 (Ille-et-Vilaine)</a>
# </span>
# <br/>
# <br/>
# <div class="interligne"><span class="confidentialite-public" qname="marqueurs"><span qname="ligne_importance_vr"> <span qname="importance_vr_reduit">***</span></span></span><span class="confidentialite-public version-element" qname="element"><span qname="ligne_horodates_element_ve"> <span class="separator-date" qname="horodates_constatation_reduit_ve">À 16h31</span></span><span qname="ligne_nature_ve">, <span class="nature" qname="nature_bouchon">Bouchon</span><span qname="lg_bouchon"> de 2,0 km</span><span qname="nbr_voies"> toutes les voies</span></span><span qname="ligne_axe_sens_pr">, <span qname="axe"> N12</span><span qname="sens_par_pole">, de Brest vers Paris</span><span qname="sens_cardinal"> (sens ouest-est</span><span qname="parenthese">)</span></span><span qname="ligne_axe_pr">, <span qname="pr">entre les PR 80 et 78</span><span qname="longueur"> (sur 2,0 km)</span></span><span qname="ligne_commune">, <span qname="commune">à Pleumeleuc</span></span><span qname="ligne_complementaire">, <span qname="toutes_voies">Sur toutes les voies</span></span></span><span class="origine" qname="origine"> ; <span qname="ligne_origine_vr"> <span qname="origine_ve_crochet_debut"> [</span><span qname="origine_vr">Origine : DIRO Rennes</span><span qname="origine_ve_crochet_fin">]</span></span></span></div>
# <div class="interligne"><span class="confidentialite-public" qname="marqueurs"><span qname="ligne_importance_vr"> <span qname="importance_vr_reduit">**</span></span></span><span class="confidentialite-public version-element" qname="element"><span qname="ligne_nature_ve"> <span class="nature" qname="nature_bouchon">Bouchon</span><span qname="lg_bouchon"> de 1,9 km</span><span qname="nbr_voies"> toutes les voies</span></span><span qname="ligne_axe_sens_pr">, <span qname="axe"> N136</span><span qname="sens_cardinal"> (sens intérieur</span><span qname="parenthese">)</span></span><span qname="ligne_axe_pr">, <span qname="pr">entre les PR 5+860 et 7+750</span><span qname="longueur"> (sur 1,9 km)</span></span><span qname="ligne_commune">, <span qname="commune">à Rennes</span></span><span qname="ligne_complementaire">, <span qname="toutes_voies">Sur toutes les voies</span></span></span><span class="origine" qname="origine"> ; <span qname="ligne_origine_vr"> <span qname="origine_ve_crochet_debut"> [</span><span qname="origine_vr">Origine : DIRO Rennes</span><span qname="origine_ve_crochet_fin">]</span></span></span></div>
# <div class="interligne"><span class="confidentialite-public" qname="marqueurs"><span qname="ligne_importance_vr"> <span qname="importance_vr_reduit">**</span></span></span><span class="confidentialite-public version-element" qname="element"><span qname="ligne_nature_ve"> <span class="nature" qname="nature_bouchon">Bouchon</span><span qname="lg_bouchon"> de 1,0 km</span><span qname="nbr_voies"> toutes les voies</span></span><span qname="ligne_axe_sens_pr">, <span qname="axe"> N136</span><span qname="sens_cardinal"> (sens extérieur</span><span qname="parenthese">)</span></span><span qname="ligne_axe_pr">, <span qname="pr">entre les PR 9 et 8</span><span qname="longueur"> (sur 1,0 km)</span></span><span qname="ligne_commune">, <span qname="commune">de Rennes à Noyal-Châtillon-sur-Seiche</span></span><span qname="ligne_complementaire">, <span qname="toutes_voies">Sur toutes les voies</span></span></span><span class="origine" qname="origine"> ; <span qname="ligne_origine_vr"> <span qname="origine_ve_crochet_debut"> [</span><span qname="origine_vr">Origine : DIRO Rennes</span><span qname="origine_ve_crochet_fin">]</span></span></span></div>
# <div class="interligne"><span class="confidentialite-public" qname="marqueurs"><span qname="ligne_importance_vr"> <span qname="importance_vr_reduit">**</span></span></span><span class="confidentialite-public version-element" qname="element"><span qname="ligne_nature_ve"> <span class="nature" qname="nature_bouchon">Bouchon</span><span qname="lg_bouchon"> de 2,5 km</span><span qname="nbr_voies"> toutes les voies</span></span><span qname="ligne_axe_sens_pr">, <span qname="axe"> N136</span><span qname="sens_cardinal"> (sens extérieur</span><span qname="parenthese">)</span></span><span qname="ligne_axe_pr">, <span qname="pr">entre les PR 12+500 et 10</span><span qname="longueur"> (sur 2,6 km)</span></span><span qname="ligne_commune">, <span qname="commune">de Saint-Jacques-de-la-Lande à Noyal-Châtillon-sur-Seiche</span></span><span qname="ligne_complementaire">, <span qname="toutes_voies">Sur toutes les voies</span></span></span><span class="origine" qname="origine"> ; <span qname="ligne_origine_vr"> <span qname="origine_ve_crochet_debut"> [</span><span qname="origine_vr">Origine : DIRO Rennes</span><span qname="origine_ve_crochet_fin">]</span></span></span></div>
# <div class="interligne"><span class="confidentialite-public" qname="marqueurs"><span qname="ligne_importance_vr"> <span qname="importance_vr_reduit">**</span></span></span><span class="confidentialite-public version-element" qname="element"><span qname="ligne_nature_ve"> <span class="nature" qname="nature_bouchon">Bouchon</span><span qname="lg_bouchon"> de 5,5 km</span><span qname="nbr_voies"> toutes les voies</span></span><span qname="ligne_axe_sens_pr">, <span qname="axe"> N136</span><span qname="sens_cardinal"> (sens intérieur</span><span qname="parenthese">)</span></span><span qname="ligne_axe_pr">, <span qname="pr">entre les PR 11+800 et 17+339</span><span qname="longueur"> (sur 5,6 km)</span></span><span qname="ligne_commune">, <span qname="commune">de Saint-Jacques-de-la-Lande à Rennes</span></span><span qname="ligne_complementaire">, <span qname="toutes_voies">Sur toutes les voies</span></span></span><span class="origine" qname="origine"> ; <span qname="ligne_origine_vr"> <span qname="origine_ve_crochet_debut"> [</span><span qname="origine_vr">Origine : DIRO Rennes</span><span qname="origine_ve_crochet_fin">]</span></span></span></div>
# <div class="interligne"><span class="confidentialite-public" qname="marqueurs"><span qname="ligne_importance_vr"> <span qname="importance_vr_reduit">**</span></span></span><span class="confidentialite-public version-element" qname="element"><span qname="ligne_nature_ve"> <span class="nature" qname="nature_bouchon">Ralentissement</span><span qname="lg_bouchon"> de 1,0 km</span><span qname="nbr_voies"> toutes les voies</span></span><span qname="ligne_axe_sens_pr">, <span qname="axe"> N136</span><span qname="sens_cardinal"> (sens extérieur</span><span qname="parenthese">)</span></span><span qname="ligne_axe_pr">, <span qname="pr">entre les PR 18 et 17</span><span qname="longueur"> (sur 1,0 km)</span></span><span qname="ligne_commune">, <span qname="commune">à Rennes</span></span><span qname="ligne_complementaire">, <span qname="toutes_voies">Sur toutes les voies</span></span></span><span class="origine" qname="origine"> ; <span qname="ligne_origine_vr"> <span qname="origine_ve_crochet_debut"> [</span><span qname="origine_vr">Origine : DIRO Rennes</span><span qname="origine_ve_crochet_fin">]</span></span></span></div>
# <div class="interligne"><span class="confidentialite-public" qname="marqueurs"><span qname="ligne_importance_vr"> <span qname="importance_vr_reduit">**</span></span></span><span class="confidentialite-public version-element" qname="element"><span qname="ligne_nature_ve"> <span class="nature" qname="nature_bouchon">Bouchon</span><span qname="lg_bouchon"> de 1,0 km</span><span qname="nbr_voies"> toutes les voies</span></span><span qname="ligne_axe_sens_pr">, <span qname="axe"> N136</span><span qname="sens_cardinal"> (sens extérieur</span><span qname="parenthese">)</span></span><span qname="ligne_axe_pr">, <span qname="pr">entre les PR 22 et 21</span><span qname="longueur"> (sur 1,0 km)</span></span><span qname="ligne_commune">, <span qname="commune">de Saint-Grégoire à Rennes</span></span><span qname="ligne_complementaire">, <span qname="toutes_voies">Sur toutes les voies</span></span></span><span class="origine" qname="origine"> ; <span qname="ligne_origine_vr"> <span qname="origine_ve_crochet_debut"> [</span><span qname="origine_vr">Origine : DIRO Rennes</span><span qname="origine_ve_crochet_fin">]</span></span></span></div>
# <br/>
# <hr/>
# <span class="rupture">
# <a name="38">Département 38 (Isère)</a>
# </span>
# <br/>
# <br/>
# <div class="interligne"><span class="confidentialite-public" qname="marqueurs"><span qname="ligne_importance_vr"> <span qname="importance_vr_reduit">**</span></span></span><span class="confidentialite-public version-element" qname="element"><span qname="ligne_nature_ve"> <span class="nature" qname="nature_bouchon">Bouchon</span><span qname="lg_bouchon"> de 0,9 km</span><span qname="nbr_voies"> toutes les voies</span></span><span qname="ligne_axe_sens_pr">, <span qname="axe"> A480</span><span qname="sens_cardinal"> (sens sud-nord</span><span qname="parenthese">)</span></span><span qname="ligne_impact">, <span qname="nature_impact_libelle">Impact : </span><span qname="nature_impact">voies neutralisées</span></span><span qname="ligne_axe_pr">, <span qname="pr">entre les PR 8+500 et 7+649</span><span qname="longueur"> (sur 0,9 km)</span></span><span qname="ligne_commune">, <span qname="commune">à Échirolles</span></span></span><span class="origine" qname="origine"> ; <span qname="ligne_origine_vr"> <span qname="origine_ve_crochet_debut"> [</span><span qname="origine_vr">Origine : SCA AREA DATEXII</span><span qname="origine_ve_crochet_fin">]</span></span></span></div>
# <div class="interligne"><span class="confidentialite-public" qname="marqueurs"><span qname="ligne_importance_vr"> <span qname="importance_vr_reduit">**</span></span></span><span class="confidentialite-public version-element" qname="element"><span qname="ligne_nature_ve"> <span class="nature" qname="nature_bouchon">Bouchon</span><span qname="lg_bouchon"> de 1,2 km</span><span qname="nbr_voies"> toutes les voies</span></span><span qname="ligne_axe_sens_pr">, <span qname="axe"> A7N</span><span qname="sens_par_pole">, de Vienne vers Lyon</span><span qname="sens_cardinal"> (sens sud-nord</span><span qname="parenthese">)</span></span><span qname="ligne_impact">, <span qname="nature_impact_libelle">Impact : </span><span qname="nature_impact">voies rétrécies</span></span><span qname="ligne_axe_pr">, <span qname="pr">entre les PR 35+680 et 34+500</span><span qname="longueur"> (sur 1,2 km)</span></span><span qname="ligne_commune">, <span qname="commune">à Reventin-Vaugris</span></span><span qname="ligne_complementaire">, <span qname="toutes_voies">Sur toutes les voies</span></span></span><span class="origine" qname="origine"> ; <span qname="ligne_origine_vr"> <span qname="origine_ve_crochet_debut"> [</span><span qname="origine_vr">Origine : GRT</span><span qname="origine_ve_crochet_fin">]</span></span></span></div>
# <div class="interligne"><span class="confidentialite-public" qname="marqueurs"><span qname="ligne_importance_vr"> <span qname="importance_vr_reduit">**</span></span></span><span class="confidentialite-public version-element" qname="element"><span qname="ligne_nature_ve"> <span class="nature" qname="nature_bouchon">Ralentissement</span><span qname="lg_bouchon"> de 0,8 km</span><span qname="nbr_voies"> toutes les voies</span></span><span qname="ligne_axe_sens_pr">, <span qname="axe"> A7N</span><span qname="sens_par_pole">, de Vienne vers Lyon</span><span qname="sens_cardinal"> (sens sud-nord</span><span qname="parenthese">)</span></span><span qname="ligne_impact">, <span qname="nature_impact_libelle">Impact : </span><span qname="nature_impact">voies rétrécies</span></span><span qname="ligne_axe_pr">, <span qname="pr">entre les PR 21 et 21-800</span><span qname="longueur"> (sur 0,8 km)</span></span><span qname="ligne_commune">, <span qname="commune">à Chasse-sur-Rhône</span></span><span qname="ligne_complementaire">, <span qname="toutes_voies">Sur toutes les voies</span></span></span><span class="origine" qname="origine"> ; <span qname="ligne_origine_vr"> <span qname="origine_ve_crochet_debut"> [</span><span qname="origine_vr">Origine : SCA ASF</span><span qname="origine_ve_crochet_fin">]</span></span></span></div>
# ...
# <br/>
# <hr/>
# <span class="rupture">
# <a name="76">Département 76 (Seine-Maritime)</a>
# </span>
# <br/>
# <br/>
# <div class="interligne"><span class="confidentialite-public" qname="marqueurs"><span qname="ligne_importance_vr"> <span qname="importance_vr_reduit">**</span></span></span><span class="confidentialite-public version-element" qname="element"><span qname="ligne_nature_ve"> <span class="nature" qname="nature_bouchon">Bouchon</span><span qname="lg_bouchon"> de 0,5 km</span><span qname="nbr_voies"> toutes les voies</span></span><span qname="ligne_horodate_fin_exception_ve">, <span class="separator-date" qname="horodate_fin_reduit_ve_evt_encours">prévu jusqu'à 19h</span></span><span qname="ligne_axe_sens_pr">, <span qname="axe"> A29</span><span qname="sens_par_pole">, de Saint Quentin vers Caen</span><span qname="sens_cardinal"> (sens est-ouest</span><span qname="parenthese">)</span></span><span qname="ligne_axe_pr">, <span qname="pr">entre les PR 24+597 et 24+97</span><span qname="longueur"> (sur 0,5 km)</span></span><span qname="ligne_commune">, <span qname="commune">de Rogerville à Oudalle</span></span></span><span class="origine" qname="origine"> ; <span qname="ligne_origine_vr"> <span qname="origine_ve_crochet_debut"> [</span><span qname="origine_vr">Origine : SCA SAPN SANEF</span><span qname="origine_ve_crochet_fin">]</span></span></span></div>
# <br/>
# <hr/>
# <span class="rupture">
# <a name="77">Département 77 (Seine-et-Marne)</a>
# </span>
# <br/>
# <br/>
# <div class="interligne"><span class="confidentialite-public" qname="marqueurs"><span qname="ligne_importance_vr"> <span qname="importance_vr_reduit">**</span></span></span><span class="confidentialite-public version-element" qname="element"><span qname="ligne_nature_ve"> <span class="nature" qname="nature_bouchon">Ralentissement</span><span qname="lg_bouchon"> de 4,3 km</span><span qname="nbr_voies"> toutes les voies</span></span><span qname="ligne_horodate_fin_exception_ve">, <span class="separator-date" qname="horodate_fin_reduit_ve_evt_encours">prévu jusqu'à 19h</span></span><span qname="ligne_axe_sens_pr">, <span qname="axe"> A4</span><span qname="sens_par_pole">, de Paris vers Strasbourg</span><span qname="sens_cardinal"> (sens sud-nord</span><span qname="parenthese">)</span></span><span qname="ligne_axe_pr">, <span qname="pr">entre les PR 12+727 et 17+35</span><span qname="longueur"> (sur 4,4 km)</span></span><span qname="ligne_departement">, <span qname="departement">entre les départements 93 (Seine-Saint-Denis) et 77 (Seine-et-Marne)</span></span><span qname="ligne_commune">, <span qname="commune">de Noisy-le-Grand à Émerainville</span></span></span><span class="origine" qname="origine"> ; <span qname="ligne_origine_vr"> <span qname="origine_ve_crochet_debut"> [</span><span qname="origine_vr">Origine : SCA SAPN SANEF</span><span qname="origine_ve_crochet_fin">]</span></span></span></div>
# <br/>
# <hr/>
# <span class="rupture">
# <a name="78">Département 78 (Yvelines)</a>
# </span>
# <br/>
# <br/>
# <div class="interligne"><span class="confidentialite-public" qname="marqueurs"><span qname="ligne_importance_vr"> <span qname="importance_vr_reduit">**</span></span></span><span class="confidentialite-public version-element" qname="element"><span qname="ligne_nature_ve"> <span class="nature" qname="nature_bouchon">Ralentissement</span><span qname="lg_bouchon"> de 2,8 km</span><span qname="nbr_voies"> toutes les voies</span></span><span qname="ligne_horodate_fin_exception_ve">, <span class="separator-date" qname="horodate_fin_reduit_ve_evt_encours">prévu jusqu'à 20h</span></span><span qname="ligne_axe_sens_pr">, <span qname="axe"> A13</span><span qname="sens_par_pole">, de Paris vers Cherbourg</span><span qname="sens_cardinal"> (sens est-ouest</span><span qname="parenthese">)</span></span><span qname="ligne_axe_pr">, <span qname="pr">entre les PR 45+498 et 48+338</span><span qname="longueur"> (sur 2,9 km)</span></span><span qname="ligne_commune">, <span qname="commune">de Guerville à Mantes-la-Ville</span></span></span><span class="origine" qname="origine"> ; <span qname="ligne_origine_vr"> <span qname="origine_ve_crochet_debut"> [</span><span qname="origine_vr">Origine : SCA SAPN SANEF</span><span qname="origine_ve_crochet_fin">]</span></span></span></div>
# <div class="interligne"><span class="confidentialite-public" qname="marqueurs"><span qname="ligne_importance_vr"> <span qname="importance_vr_reduit">*</span></span></span><span class="confidentialite-public version-element" qname="element"><span qname="ligne_nature_ve"> <span class="nature" qname="nature_bouchon">Bouchon</span><span qname="nbr_voies"> sur 1 voie</span></span><span qname="ligne_horodate_fin_exception_ve">, <span class="separator-date" qname="horodate_fin_reduit_ve_evt_encours">prévu jusqu'à 20h</span></span><span qname="ligne_axe_sens_pr">, <span qname="axe">A13</span><span qname="sens_par_pole">, de Paris vers Cherbourg</span><span qname="sens_cardinal"> (sens est-ouest</span><span qname="parenthese">)</span></span><span qname="ligne_axe_pr">, <span qname="pr">au PR 48+104</span></span><span qname="ligne_commune">, <span qname="commune">à Mantes-la-Ville</span></span><span qname="ligne_complementaire">, <span qname="bretelle">situé sur la bretelle de sortie  de l'échangeur</span></span></span><span class="origine" qname="origine"> ; <span qname="ligne_origine_vr"> <span qname="origine_ve_crochet_debut"> [</span><span qname="origine_vr">Origine : SCA SAPN SANEF</span><span qname="origine_ve_crochet_fin">]</span></span></span></div>
# <div class="interligne"><span class="confidentialite-public" qname="marqueurs"><span qname="ligne_importance_vr"> <span qname="importance_vr_reduit">*</span></span></span><span class="confidentialite-public version-element" qname="element"><span qname="ligne_nature_ve"> <span class="nature" qname="nature_bouchon">Bouchon</span><span qname="nbr_voies"> toutes les voies</span></span><span qname="ligne_horodate_fin_exception_ve">, <span class="separator-date" qname="horodate_fin_reduit_ve_evt_encours">prévu jusqu'à 20h</span></span><span qname="ligne_axe_sens_pr">, <span qname="axe">A14</span><span qname="sens_par_pole">, de Orgeval (A13) vers La Défense</span><span qname="sens_cardinal"> (sens ouest-est</span><span qname="parenthese">)</span></span><span qname="ligne_axe_pr">, <span qname="pr">au PR 7+763</span></span><span qname="ligne_commune">, <span qname="commune">à Carrières-sur-Seine</span></span></span><span class="origine" qname="origine"> ; <span qname="ligne_origine_vr"> <span qname="origine_ve_crochet_debut"> [</span><span qname="origine_vr">Origine : SCA SAPN SANEF</span><span qname="origine_ve_crochet_fin">]</span></span></span></div>
# <div class="interligne"><span class="confidentialite-public" qname="marqueurs"><span qname="ligne_importance_vr"> <span qname="importance_vr_reduit">*</span></span></span><span class="confidentialite-public version-element" qname="element"><span qname="ligne_nature_ve"> <span class="nature" qname="nature_bouchon">Bouchon</span><span qname="lg_bouchon"> de 0,3 km</span><span qname="nbr_voies"> toutes les voies</span></span><span qname="ligne_horodate_fin_exception_ve">, <span class="separator-date" qname="horodate_fin_reduit_ve_evt_encours">prévu jusqu'à 19h</span></span><span qname="ligne_axe_sens_pr">, <span qname="axe"> A14</span><span qname="sens_par_pole">, de La Défense vers Orgeval (A13)</span><span qname="sens_cardinal"> (sens est-ouest</span><span qname="parenthese">)</span></span><span qname="ligne_axe_pr">, <span qname="pr">entre les PR 7+469 et 7+769</span><span qname="longueur"> (sur 0,3 km)</span></span><span qname="ligne_commune">, <span qname="commune">à Carrières-sur-Seine</span></span></span><span class="origine" qname="origine"> ; <span qname="ligne_origine_vr"> <span qname="origine_ve_crochet_debut"> [</span><span qname="origine_vr">Origine : SCA SAPN SANEF</span><span qname="origine_ve_crochet_fin">]</span></span></span></div>
# <br/>
# <hr/>
# <span class="rupture">
# <a name="82">Département 82 (Tarn-et-Garonne)</a>
# </span>
# <br/>
# <br/>
# <div class="interligne"><span class="confidentialite-public" qname="marqueurs"><span qname="ligne_importance_vr"> <span qname="importance_vr_reduit">**</span></span></span><span class="confidentialite-public version-element" qname="element"><span qname="ligne_nature_ve"> <span class="nature" qname="nature_bouchon">Ralentissement</span><span qname="lg_bouchon"> de 4,0 km</span><span qname="nbr_voies"> toutes les voies</span></span><span qname="ligne_axe_sens_pr">, <span qname="axe"> A62</span><span qname="sens_par_pole">, de Toulouse vers Bordeaux</span><span qname="sens_cardinal"> (sens sud-nord</span><span qname="parenthese">)</span></span><span qname="ligne_impact">, <span qname="nature_impact_libelle">Impact : </span><span qname="nature_impact">voies rétrécies</span></span><span qname="ligne_axe_pr">, <span qname="pr">entre les PR 196 et 192</span><span qname="longueur"> (sur 4,0 km)</span></span><span qname="ligne_commune">, <span qname="commune">de Campsas à Montbartier</span></span><span qname="ligne_complementaire">, <span qname="toutes_voies">Sur toutes les voies</span></span></span><span class="origine" qname="origine"> ; <span qname="ligne_origine_vr"> <span qname="origine_ve_crochet_debut"> [</span><span qname="origine_vr">Origine : SCA ASF</span><span qname="origine_ve_crochet_fin">]</span></span></span></div>
# <br/>
# <hr/>
# <span class="rupture">
# <a name="83">Département 83 (Var)</a>
# </span>
# <br/>
# <br/>
# <div class="interligne"><span class="confidentialite-public" qname="marqueurs"><span qname="ligne_importance_vr"> <span qname="importance_vr_reduit">**</span></span></span><span class="confidentialite-public version-element" qname="element"><span qname="ligne_nature_ve"> <span class="nature" qname="nature_bouchon">Bouchon</span><span qname="lg_bouchon"> de 1,5 km</span></span><span qname="ligne_axe_sens_pr">, <span qname="axe"> A50</span><span qname="sens_par_pole">, de Marseille vers Toulon</span><span qname="sens_cardinal"> (sens ouest-est</span><span qname="parenthese">)</span></span><span qname="ligne_axe_pr">, <span qname="pr">entre les PR 67+116 et 68+555</span><span qname="longueur"> (sur 1,5 km)</span></span><span qname="ligne_commune">, <span qname="commune">à Toulon</span></span><span qname="ligne_commentaire_public">, <span class="text-multiline" qname="commentaire_public">Trafic ralenti.</span></span></span><span class="origine" qname="origine"> ; <span qname="ligne_origine_vr"> <span qname="origine_ve_crochet_debut"> [</span><span qname="origine_vr">Origine : SCA Escota (fr204)</span><span qname="origine_ve_crochet_fin">]</span></span></span></div>
# <div class="interligne"><span class="confidentialite-public" qname="marqueurs"><span qname="ligne_importance_vr"> <span qname="importance_vr_reduit">**</span></span></span><span class="confidentialite-public version-element" qname="element"><span qname="ligne_nature_ve"> <span class="nature" qname="nature_bouchon">Bouchon</span><span qname="lg_bouchon"> de 5,5 km</span><span qname="circulation">, circulation bloquée</span></span><span qname="ligne_axe_sens_pr">, <span qname="axe"> A57</span><span qname="sens_par_pole">, de Le Cannet des Maures vers Toulon</span><span qname="sens_cardinal"> (sens nord-sud</span><span qname="parenthese">)</span></span><span qname="ligne_axe_pr">, <span qname="pr">entre les PR 7+130 et 1+608</span><span qname="longueur"> (sur 5,5 km)</span></span><span qname="ligne_commune">, <span qname="commune">de La Garde à Toulon</span></span><span qname="ligne_commentaire_public">, <span class="text-multiline" qname="commentaire_public">Trafic bouche.</span></span></span><span class="origine" qname="origine"> ; <span qname="ligne_origine_vr"> <span qname="origine_ve_crochet_debut"> [</span><span qname="origine_vr">Origine : SCA Escota (fr204)</span><span qname="origine_ve_crochet_fin">]</span></span></span></div>
# <div class="interligne"><span class="confidentialite-public" qname="marqueurs"><span qname="ligne_importance_vr"> <span qname="importance_vr_reduit">**</span></span></span><span class="confidentialite-public version-element" qname="element"><span qname="ligne_nature_ve"> <span class="nature" qname="nature_bouchon">Bouchon</span><span qname="lg_bouchon"> de 2,5 km</span></span><span qname="ligne_axe_sens_pr">, <span qname="axe"> A57</span><span qname="sens_par_pole">, de Toulon vers Le Cannet des Maures</span><span qname="sens_cardinal"> (sens sud-nord</span><span qname="parenthese">)</span></span><span qname="ligne_axe_pr">, <span qname="pr">entre les PR 0 et 2+513</span><span qname="longueur"> (sur 2,5 km)</span></span><span qname="ligne_commune">, <span qname="commune">à Toulon</span></span><span qname="ligne_commentaire_public">, <span class="text-multiline" qname="commentaire_public">Trafic ralenti.</span></span></span><span class="origine" qname="origine"> ; <span qname="ligne_origine_vr"> <span qname="origine_ve_crochet_debut"> [</span><span qname="origine_vr">Origine : SCA Escota (fr204)</span><span qname="origine_ve_crochet_fin">]</span></span></span></div>
# <div class="interligne"><span class="confidentialite-public" qname="marqueurs"><span qname="ligne_importance_vr"> <span qname="importance_vr_reduit">**</span></span></span><span class="confidentialite-public version-element" qname="element"><span qname="ligne_nature_ve"> <span class="nature" qname="nature_bouchon">Bouchon</span><span qname="lg_bouchon"> de 4,0 km</span></span><span qname="ligne_axe_sens_pr">, <span qname="axe"> A57</span><span qname="sens_par_pole">, de Toulon vers Le Cannet des Maures</span><span qname="sens_cardinal"> (sens sud-nord</span><span qname="parenthese">)</span></span><span qname="ligne_axe_pr">, <span qname="pr">entre les PR 6+968 et 10+968</span><span qname="longueur"> (sur 4,0 km)</span></span><span qname="ligne_commune">, <span qname="commune">de La Garde à Solliès-Ville</span></span><span qname="ligne_commentaire_public">, <span class="text-multiline" qname="commentaire_public">Trafic ralenti.</span></span></span><span class="origine" qname="origine"> ; <span qname="ligne_origine_vr"> <span qname="origine_ve_crochet_debut"> [</span><span qname="origine_vr">Origine : SCA Escota (fr204)</span><span qname="origine_ve_crochet_fin">]</span></span></span></div>
# <br/>
# <hr/>
# <span class="rupture">
# <a name="93">Département 93 (Seine-Saint-Denis)</a>
# </span>
# <br/>
# <br/>
# <div class="interligne"><span class="confidentialite-public" qname="marqueurs"><span qname="ligne_importance_vr"> <span qname="importance_vr_reduit">***</span></span></span><span class="confidentialite-public version-element" qname="element"><span qname="ligne_nature_ve"> <span class="nature" qname="nature_bouchon">Ralentissement</span><span qname="lg_bouchon"> de 11,3 km</span><span qname="nbr_voies"> toutes les voies</span></span><span qname="ligne_horodate_fin_exception_ve">, <span class="separator-date" qname="horodate_fin_reduit_ve_evt_encours">prévu jusqu'à 19h</span></span><span qname="ligne_axe_sens_pr">, <span qname="axe"> A4</span><span qname="sens_par_pole">, de Strasbourg vers Paris</span><span qname="sens_cardinal"> (sens est-ouest</span><span qname="parenthese">)</span></span><span qname="ligne_axe_pr">, <span qname="pr">entre les PR 24+36 et 12+728</span><span qname="longueur"> (sur 11,4 km)</span></span><span qname="ligne_departement">, <span qname="departement">entre les départements 77 (Seine-et-Marne) et 93 (Seine-Saint-Denis)</span></span><span qname="ligne_commune">, <span qname="commune">de Bussy-Saint-Georges à Noisy-le-Grand</span></span></span><span class="origine" qname="origine"> ; <span qname="ligne_origine_vr"> <span qname="origine_ve_crochet_debut"> [</span><span qname="origine_vr">Origine : SCA SAPN SANEF</span><span qname="origine_ve_crochet_fin">]</span></span></span></div>
# <br/>
# <hr/>
# </body>
# </html>

# %%
def process_data(next_element, keys, qnames, importance, department_name, df):
    data = {}

    for key, qname in zip(keys, qnames):
        try:
            element = next_element.find('span', {'qname': qname})
            element = next_element.find('span', class_=qname) if not element else element # if qname is not found, try with class
            data[key] = element.get_text(strip=True) if element else None
        except AttributeError:
            data[key] = None

    data['date'] = d
    data['department'] = department_name
    data['importance'] = len(importance)
    # data['nature'] = nature

    new_row_df = pd.DataFrame(data, index=[0])
    updated_df = pd.concat([df, new_row_df], ignore_index=True)

    """
    print(f"Importance: {len(importance)}\nNature: {nature}\n")
    for key, value in data.items():
        print(f"{key}: {value}")
    # print("")
    # print("Raw :", next_element.get_text(strip=True))
    print("---------------------------------------------")
    print('')
    """
    return updated_df

# %%
data_folder = 'data'
keys = ['nature', 'horodate', 'axe', 'sens_cardinal', 'point_repere', 'longueur_pr', 'commune']
qnames = ['nature', 'ligne_horodate_fin_exception_ve', 'axe', 'sens_cardinal', 'pr', 'longueur', 'commune']
columns = ['date','department', 'importance'] + keys

if not os.path.exists(data_folder):
    os.makedirs(data_folder)
if not os.path.exists(data_folder + '/bison_fute_bouchons.csv'):
    columns = ['date','department', 'importance', 'nature']
    df = pd.DataFrame(columns=columns)
else:
    df = pd.read_csv(data_folder + '/bison_fute_bouchons_raw.csv')

columns
# Out:
# ['date',
#  'department',
#  'importance',
#  'nature',
#  'horodate',
#  'axe',
#  'sens_cardinal',
#  'point_repere',
#  'longueur_pr',
#  'commune']

# %%
departments = bsobj.find_all('span', class_='rupture')
initial_rows = df.shape[0]

# TODO: heurodate des bouchons + cas de plusieurs bouchons sur une meme ligne

for department in departments:
    department_name = department.find('a').get_text(strip=True)
    # print(department_name)
    # print("=============================================")
    HTML_DOC = '<div class="interligne"><span qname="marqueurs" class="confidentialite-public"><span qname="ligne_importance_vr"> <span qname="importance_vr_reduit">**</span></span></span><span qname="element" class="confidentialite-public version-element"><span qname="ligne_nature_ve"> <span class="nature" qname="nature_bouchon">Bouchon</span><span qname="lg_bouchon"> de 0,7 km</span><span qname="nbr_voies"> toutes les voies</span></span><span qname="ligne_axe_sens_pr">, <span qname="axe"> M901</span><span qname="sens_cardinal"> (sens nord-sud</span><span qname="parenthese">)</span></span><span qname="ligne_axe_pr">, <span qname="longueur"> (sur 0,7 km environ)</span></span><span qname="ligne_commune">, <span qname="commune">à Toulouse</span></span><span qname="ligne_complementaire">, <span qname="toutes_voies">Sur toutes les voies</span></span></span><span qname="element" class="confidentialite-public version-element"> ; <span qname="ligne_horodates_element_ve"> <span class="separator-date" qname="horodates_constatation_reduit_ve">À 16h29</span></span><span qname="ligne_nature_ve">, <span class="nature" qname="nature_bouchon">Bouchon</span><span qname="lg_bouchon"> de 2,6 km</span><span qname="nbr_voies"> sur 0 voie</span></span><span qname="ligne_axe_sens_pr">, <span qname="axe"> A621</span><span qname="sens_par_pole">, de Toulouse vers Aéroport Blagnac</span><span qname="sens_cardinal"> (sens est-ouest</span><span qname="parenthese">)</span></span><span qname="ligne_axe_pr">, <span qname="pr">entre les PR 1+188 et 3+784</span><span qname="longueur"> (sur 2,6 km)</span></span><span qname="ligne_commune">, <span qname="commune">de Toulouse à Blagnac</span></span></span><span qname="origine" class="origine"> ; <span qname="ligne_origine_vr"> <span qname="origine_ve_crochet_debut"> [</span><span qname="origine_vr">Origine : DIRSO Toulouse Sagacité</span><span qname="origine_ve_crochet_fin">]</span></span></span></div>'
    next_element = department.find_next_sibling()
    # next_element = BeautifulSoup(HTML_DOC, 'html.parser')
    while next_element and next_element.name != 'span' and 'rupture' not in next_element.get('class', []):
        if next_element.name == 'div' and 'interligne' in next_element['class'][0]:
            elements = next_element.find_all('span', {'qname': 'element'})
            for element in elements:
                importance = next_element.find('span', {'qname': 'importance_vr_reduit'}).get_text(strip=True)
                # nature = next_element.find('span', class_='nature').get_text(strip=True)
                df = process_data(element, keys, qnames, importance, department_name, df)

        next_element = next_element.find_next_sibling()

df.drop_duplicates(inplace=True) # I don't want to add elements I already have in my df
print(f"Added {df.shape[0] - initial_rows} new rows")
# Out:
# Added 13 new rows

# %%
df
# Out:
#            date                          department  importance  \
# 0    2024-04-25    Département 06 (Alpes-Maritimes)           2
# 1    2024-04-25    Département 06 (Alpes-Maritimes)           2
# 2    2024-04-25    Département 06 (Alpes-Maritimes)           2
# 3    2024-04-25    Département 06 (Alpes-Maritimes)           2
# 4    2024-04-25    Département 06 (Alpes-Maritimes)           2
# ..          ...                                 ...         ...
# 154  2024-04-25           Département 78 (Yvelines)           2
# 155  2024-04-25           Département 78 (Yvelines)           1
# 156  2024-04-25           Département 78 (Yvelines)           1
# 157  2024-04-25           Département 78 (Yvelines)           1
# 163  2024-04-25  Département 93 (Seine-Saint-Denis)           3
#
#              nature            horodate  axe    sens_cardinal  \
# 0           Bouchon                 NaN   A8  (sens ouest-est
# 1           Bouchon                 NaN   A8  (sens est-ouest
# 2           Bouchon                 NaN   A8  (sens est-ouest
# 3           Bouchon                 NaN   A8  (sens est-ouest
# 4           Bouchon                 NaN   A8  (sens est-ouest
# ..              ...                 ...  ...              ...
# 154  Ralentissement  ,prévu jusqu'à 20h  A13  (sens est-ouest
# 155         Bouchon  ,prévu jusqu'à 20h  A13  (sens est-ouest
# 156         Bouchon  ,prévu jusqu'à 20h  A14  (sens ouest-est
# 157         Bouchon  ,prévu jusqu'à 19h  A14  (sens est-ouest
# 163  Ralentissement  ,prévu jusqu'à 19h   A4  (sens est-ouest
#
#                         point_repere    longueur_pr  \
# 0    entre les PR 164+199 et 165+199   (sur 1,0 km)
# 1    entre les PR 186+536 et 185+536   (sur 1,0 km)
# 2    entre les PR 190+629 et 189+129   (sur 1,5 km)
# 3    entre les PR 199+514 et 193+514   (sur 6,0 km)
# 4    entre les PR 209+903 et 207+403   (sur 2,5 km)
# ..                               ...            ...
# 154    entre les PR 45+498 et 48+338   (sur 2,9 km)
# 155                     au PR 48+104           None
# 156                      au PR 7+763           None
# 157      entre les PR 7+469 et 7+769   (sur 0,3 km)
# 163     entre les PR 24+36 et 12+728  (sur 11,4 km)
#
#                                      commune
# 0                                  à Mougins
# 1                                     à Nice
# 2                                     à Nice
# 3                                     à Nice
# 4                  de La Turbie à La Trinité
# ..                                       ...
# 154           de Guerville à Mantes-la-Ville
# 155                        à Mantes-la-Ville
# 156                    à Carrières-sur-Seine
# 157                    à Carrières-sur-Seine
# 163  de Bussy-Saint-Georges à Noisy-le-Grand
#
# [95 rows x 10 columns]

# %% [markdown]
# I opted for a general approach in the end
# - `['horodate', 'axe', 'sens_cardinal', 'point_repere', 'longueur_pr', 'commune']` were the most common features
# - I you really want to be precise and exploit every bits of data each classes have, you can still write an if statement on `nature` like this:
#
# ```py
# if next_element.name == 'div' and 'interligne' in next_element['class'][0]:
#     importance = next_element.find('span', {'qname': 'importance_vr_reduit'}).get_text(strip=True)
#     nature = next_element.find('span', class_='nature').get_text(strip=True)
#
#     if nature.lower == 'your_class_here': # 'accident' for example
#         keys = [...] # the name you want to give the features in the dataframe
#         qnames = [...] # the actual qnames in the html object for your specific case
#         df = process_data(next_element, keys, qnames, importance, nature, department_name, df)
#     else:
#         df = process_data(next_element, keys, qnames, importance, nature, department_name, df)
# ```
# - bear in mind, you also need to update the cell above so that the dataframe recognize the keys as its columns in here:
# ```py
# keys = ['horodate', 'axe', 'sens_cardinal', 'point_repere', 'longueur_pr', 'commune']
# qnames = ['ligne_horodate_fin_exception_ve', 'axe', 'sens_cardinal', 'pr', 'longueur', 'commune']
# columns = ['date','department', 'importance', 'nature'] + keys # this should have every feature you added
# df = pd.DataFrame(columns=columns)
# ```

# %%
print(df.shape)
df.head(3)
# Out:
# (95, 10)
#          date                        department  importance   nature horodate  \
# 0  2024-04-25  Département 06 (Alpes-Maritimes)           2  Bouchon      NaN
# 1  2024-04-25  Département 06 (Alpes-Maritimes)           2  Bouchon      NaN
# 2  2024-04-25  Département 06 (Alpes-Maritimes)           2  Bouchon      NaN
#
#   axe    sens_cardinal                     point_repere   longueur_pr  \
# 0  A8  (sens ouest-est  entre les PR 164+199 et 165+199  (sur 1,0 km)
# 1  A8  (sens est-ouest  entre les PR 186+536 et 185+536  (sur 1,0 km)
# 2  A8  (sens est-ouest  entre les PR 190+629 et 189+129  (sur 1,5 km)
#
#      commune
# 0  à Mougins
# 1     à Nice
# 2     à Nice

# %%
df.to_csv(data_folder + f'/bison_fute_bouchons_raw.csv', index=False)

# %% [markdown]
# As you can see, we might want to do some cleaning, I'll leave some of the feature cleaning to do:
# - for example, the feature `commune` can be at a specific commune, but also in between two communes, how do we handle that ? The answer might depend on you use case so I'll leave it to you
#
# ### sens cardinal

# %%
df.fillna(value=np.nan, inplace=True)
df['sens_cardinal'].unique()
# Out:
# array(['(sens ouest-est', '(sens est-ouest', '(sens sud-nord',
#        '(sens nord-sud', '(sens intérieur', '(sens extérieur', nan],
#       dtype=object)

# %%
df['sens_cardinal'] = df['sens_cardinal'].str.replace(r'^\(|sens(?=\s)', '', regex=True).str.strip()
df['sens_cardinal'].unique()
# Out:
# array(['ouest-est', 'est-ouest', 'sud-nord', 'nord-sud', 'intérieur',
#        'extérieur', nan], dtype=object)

# %% [markdown]
# ### longueur point repère

# %%
df['longueur_pr'].unique()
# Out:
# array(['(sur 1,0 km)', '(sur 1,5 km)', '(sur 6,0 km)', '(sur 2,5 km)',
#        nan, '(sur 0,5 km)', '(sur 3,9 km)', '(sur 2,6 km)',
#        '(sur 1,4 km)', '(sur 2,0 km)', '(sur 5,0 km)', '(sur 3,5 km)',
#        '(sur 2,8 km)', '(sur 0,3 km)', '(sur 1,9 km)', '(sur 5,6 km)',
#        '(sur 0,9 km)', '(sur 1,2 km)', '(sur 0,8 km)',
#        '(sur 0,5 km environ)', '(sur 2,4 km environ)', '(sur 4,0 km)',
#        '(sur 3,0 km)', '(sur 2,4 km)', '(sur 1,1 km)', '(sur 1,3 km)',
#        '(sur 0,7 km)', '(sur 4,8 km)', '(sur 2,3 km)',
#        '(sur 1,5 km environ)', '(sur 4,4 km)', '(sur 2,9 km)',
#        '(sur 5,5 km)', '(sur 11,4 km)'], dtype=object)

# %%
df['longueur_pr'] = df['longueur_pr'].str.replace(' environ', '').str.replace('(sur ', '').str.replace(' km)', '').str.replace('de longueur indéterminée', 'nan')
df['longueur_pr'] = df['longueur_pr'].str.replace(',', '.')
df['longueur_pr'].unique()
# Out:
# array(['1.0', '1.5', '6.0', '2.5', nan, '0.5', '3.9', '2.6', '1.4', '2.0',
#        '5.0', '3.5', '2.8', '0.3', '1.9', '5.6', '0.9', '1.2', '0.8',
#        '2.4', '4.0', '3.0', '1.1', '1.3', '0.7', '4.8', '2.3', '4.4',
#        '2.9', '5.5', '11.4'], dtype=object)

# %%
df['longueur_pr'] = df['longueur_pr'].apply(lambda x: float(x) if x != 'nan' else np.nan)
df['longueur_pr'].unique()
# Out:
# array([ 1. ,  1.5,  6. ,  2.5,  nan,  0.5,  3.9,  2.6,  1.4,  2. ,  5. ,
#         3.5,  2.8,  0.3,  1.9,  5.6,  0.9,  1.2,  0.8,  2.4,  4. ,  3. ,
#         1.1,  1.3,  0.7,  4.8,  2.3,  4.4,  2.9,  5.5, 11.4])

# %%
df = df.rename(columns={'longueur_pr': 'longueur_pr (km)'})
df.head(3)
# Out:
#          date                        department  importance   nature horodate  \
# 0  2024-04-25  Département 06 (Alpes-Maritimes)           2  Bouchon      NaN
# 1  2024-04-25  Département 06 (Alpes-Maritimes)           2  Bouchon      NaN
# 2  2024-04-25  Département 06 (Alpes-Maritimes)           2  Bouchon      NaN
#
#   axe sens_cardinal                     point_repere  longueur_pr (km)  \
# 0  A8     ouest-est  entre les PR 164+199 et 165+199               1.0
# 1  A8     est-ouest  entre les PR 186+536 et 185+536               1.0
# 2  A8     est-ouest  entre les PR 190+629 et 189+129               1.5
#
#      commune
# 0  à Mougins
# 1     à Nice
# 2     à Nice

# %%
df['department'].unique()
# Out:
# array(['Département 06 (Alpes-Maritimes)',
#        'Département 13 (Bouches-du-Rhône)', 'Département 25 (Doubs)',
#        'Département 26 (Drôme)', 'Département 28 (Eure-et-Loir)',
#        'Département 29 (Finistère)', 'Département 31 (Haute-Garonne)',
#        'Département 33 (Gironde)', 'Département 34 (Hérault)',
#        'Département 35 (Ille-et-Vilaine)', 'Département 38 (Isère)',
#        'Département 42 (Loire)', 'Département 44 (Loire-Atlantique)',
#        'Département 64 (Pyrénées-Atlantiques)',
#        'Département 66 (Pyrénées-Orientales)', 'Département 69 (Rhône)',
#        'Département 73 (Savoie)', 'Département 74 (Haute-Savoie)',
#        'Département 76 (Seine-Maritime)',
#        'Département 77 (Seine-et-Marne)', 'Département 78 (Yvelines)',
#        'Département 82 (Tarn-et-Garonne)', 'Département 83 (Var)',
#        'Département 93 (Seine-Saint-Denis)'], dtype=object)

# %%
# Extract department number and name
df['department_number'] = df['department'].str.extract(r'Département (\d+)')
df['department_name'] = df['department'].str.extract(r'\(([^()]+)\)')

# Display the first few rows to verify the result
print(df[['department', 'department_number', 'department_name']].head())
# Out:
#                          department department_number  department_name
# 0  Département 06 (Alpes-Maritimes)                06  Alpes-Maritimes
# 1  Département 06 (Alpes-Maritimes)                06  Alpes-Maritimes
# 2  Département 06 (Alpes-Maritimes)                06  Alpes-Maritimes
# 3  Département 06 (Alpes-Maritimes)                06  Alpes-Maritimes
# 4  Département 06 (Alpes-Maritimes)                06  Alpes-Maritimes

# %%
df.tail(3)
# Out:
#            date                          department  importance  \
# 156  2024-04-25           Département 78 (Yvelines)           1
# 157  2024-04-25           Département 78 (Yvelines)           1
# 163  2024-04-25  Département 93 (Seine-Saint-Denis)           3
#
#              nature            horodate  axe sens_cardinal  \
# 156         Bouchon  ,prévu jusqu'à 20h  A14     ouest-est
# 157         Bouchon  ,prévu jusqu'à 19h  A14     est-ouest
# 163  Ralentissement  ,prévu jusqu'à 19h   A4     est-ouest
#
#                      point_repere  longueur_pr (km)  \
# 156                   au PR 7+763               NaN
# 157   entre les PR 7+469 et 7+769               0.3
# 163  entre les PR 24+36 et 12+728              11.4
#
#                                      commune department_number  \
# 156                    à Carrières-sur-Seine                78
# 157                    à Carrières-sur-Seine                78
# 163  de Bussy-Saint-Georges à Noisy-le-Grand                93
#
#        department_name
# 156           Yvelines
# 157           Yvelines
# 163  Seine-Saint-Denis

# %%
df.drop(columns=['department'], inplace=True)
new_order = ['date', 'department_number', 'department_name'] + [col for col in df.columns if col not in ['date', 'department_number', 'department_name']]
df = df[new_order]

df.head(3)
# Out:
#          date department_number  department_name  importance   nature  \
# 0  2024-04-25                06  Alpes-Maritimes           2  Bouchon
# 1  2024-04-25                06  Alpes-Maritimes           2  Bouchon
# 2  2024-04-25                06  Alpes-Maritimes           2  Bouchon
#
#   horodate axe sens_cardinal                     point_repere  \
# 0      NaN  A8     ouest-est  entre les PR 164+199 et 165+199
# 1      NaN  A8     est-ouest  entre les PR 186+536 et 185+536
# 2      NaN  A8     est-ouest  entre les PR 190+629 et 189+129
#
#    longueur_pr (km)    commune
# 0               1.0  à Mougins
# 1               1.0     à Nice
# 2               1.5     à Nice

# %%
df.to_csv(f'data/bison_fute_bouchons.csv', index=False)

# %%
df.sort_values(by=['department_number'], inplace=True)
df
# Out:
#            date department_number    department_name  importance  \
# 0    2024-04-25                06    Alpes-Maritimes           2
# 1    2024-04-25                06    Alpes-Maritimes           2
# 2    2024-04-25                06    Alpes-Maritimes           2
# 3    2024-04-25                06    Alpes-Maritimes           2
# 4    2024-04-25                06    Alpes-Maritimes           2
# ..          ...               ...                ...         ...
# 79   2024-04-25                83                Var           2
# 78   2024-04-25                83                Var           2
# 77   2024-04-25                83                Var           2
# 81   2024-04-25                93  Seine-Saint-Denis           3
# 163  2024-04-25                93  Seine-Saint-Denis           3
#
#              nature            horodate  axe sens_cardinal  \
# 0           Bouchon                 NaN   A8     ouest-est
# 1           Bouchon                 NaN   A8     est-ouest
# 2           Bouchon                 NaN   A8     est-ouest
# 3           Bouchon                 NaN   A8     est-ouest
# 4           Bouchon                 NaN   A8     est-ouest
# ..              ...                 ...  ...           ...
# 79          Bouchon                 NaN  A57      sud-nord
# 78          Bouchon                 NaN  A57      nord-sud
# 77          Bouchon                 NaN  A50     ouest-est
# 81   Ralentissement                 NaN   A4     est-ouest
# 163  Ralentissement  ,prévu jusqu'à 19h   A4     est-ouest
#
#                         point_repere  longueur_pr (km)  \
# 0    entre les PR 164+199 et 165+199               1.0
# 1    entre les PR 186+536 et 185+536               1.0
# 2    entre les PR 190+629 et 189+129               1.5
# 3    entre les PR 199+514 et 193+514               6.0
# 4    entre les PR 209+903 et 207+403               2.5
# ..                               ...               ...
# 79           entre les PR 0 et 2+513               2.5
# 78       entre les PR 7+130 et 1+608               5.5
# 77     entre les PR 67+116 et 68+555               1.5
# 81      entre les PR 24+36 et 12+728              11.4
# 163     entre les PR 24+36 et 12+728              11.4
#
#                                      commune
# 0                                  à Mougins
# 1                                     à Nice
# 2                                     à Nice
# 3                                     à Nice
# 4                  de La Turbie à La Trinité
# ..                                       ...
# 79                                  à Toulon
# 78                      de La Garde à Toulon
# 77                                  à Toulon
# 81   de Bussy-Saint-Georges à Noisy-le-Grand
# 163  de Bussy-Saint-Georges à Noisy-le-Grand
#
# [95 rows x 11 columns]

# %%
import pandas as pd

all_years = pd.DataFrame()
for year in range(2019, 2023):
    print(f"Processing data for year {year}")
    # Lire le CSV dans un DataFrame pandas
    df = pd.read_csv(f"files/caracteristiques-{year}.csv", sep=";")

    # Convertir les colonnes "jour", "mois" et "an" en une colonne "date" au format '%Y-%m-%d'
    df['date_entree'] = pd.to_datetime(df[['an', 'mois', 'jour']].astype(str).agg('-'.join, axis=1))

    # Grouper les données par date et par département, puis compter le nombre d'accidents
    result = df.groupby(['date_entree', 'dep']).size().reset_index(name='nb_accidents')

    all_years = pd.concat([all_years, result])

# Enregistrer les résultats dans un nouveau CSV
all_years.to_csv("nombre_accidents_par_date_par_departement.csv", index=False)
# Out:
# Processing data for year 2019
# Processing data for year 2020
# Processing data for year 2021
# Processing data for year 2022
